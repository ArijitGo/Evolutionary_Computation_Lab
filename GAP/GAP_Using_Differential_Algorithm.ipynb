[22,14,19,7,5,20,19,5,20,7,12,8,13,18,16,9,23,16,16,9,25,8,13,16,6,8,5,18,12,5,12,16,12,25,5,24,23,23,25,22,17,17,21,24,16,7,17,9,13,24,22,25,25,23,12,12,8,24,14,8],

[17,10,18,13,14,18,6,6,11,9,12,20,15,12,18,18,11,7,9,25,13,9,10,9,15,10,19,15,15,14,25,6,12,21,9,10,18,20,13,17,17,21,15,9,22,11,14,14,13,16,12,5,14,18,24,9,19,14,9,24],

[24,23,6,13,9,17,18,21,10,15,15,18,14,15,11,24,20,24,16,20,23,25,9,21,21,13,9,24,12,8,14,21,16,25,20,23,8,16,20,10,5,16,11,20,10,11,21,15,12,12,21,10,19,18,10,25,23,16,8,25],

[5,21,24,13,21,11,18,12,24,22,20,21,16,18,8,25,7,19,11,12,18,5,15,7,12,5,23,16,12,5,8,24,25,10,13,24,22,20,12,16,18,9,21,17,19,6,21,12,6,9,24,10,8,13,13,13,23,25,8,22],

[9,19,23,7,5,8,16,17,21,15,15,12,21,24,15,6,7,11,5,13,10,16,19,9,22,8,21,17,7,8,25,23,20,8,14,16,5,16,5,10,17,6,18,9,19,9,11,18,23,14,24,13,20,10,22,19,6,15,18,15],

[23,15,16,20,19,23,8,15,24,25,25,5,13,14,12,25,5,11,23,24,18,7,17,10,25,21,13,19,18,6,8,9,21,18,5,12,8,7,19,24,7,9,22,7,9,10,14,24,22,24,15,16,11,19,18,18,16,8,6,8],

[10,14,24,13,18,11,13,24,22,7,12,17,23,12,15,5,5,16,20,22,18,12,20,12,9,5,7,6,25,6,7,13,7,23,21,21,18,8,23,7,11,9,15,19,9,13,22,24,18,14,11,15,15,18,22,13,17,14,11,11]
]

capacity = [79, 67, 74, 73, 67, 78, 73, 68, 73, 69]

# %%
import numpy as np
import random
import time
import matplotlib.pyplot as plt

# ----------------------------------------------------------------------
# Parameters
# ----------------------------------------------------------------------
m = len(cost)          # number of agents (10)
n = len(cost[0])       # number of jobs (60)
Np = 200               # population size
T = 2000               # number of generations
F = 0.95               # scaling factor
pc = 0.1               # crossover probability
lambda_penalty = 1e9   # very high penalty (repair ensures feasibility)

# ----------------------------------------------------------------------
# Helper: compute resource usage per agent
# ----------------------------------------------------------------------
def get_usage(x):
    used = [0] * m
    for j, agent in enumerate(x):
        agent_idx = agent - 1
        used[agent_idx] += resource[agent_idx][j]
    return used

# ----------------------------------------------------------------------
# Repair function: makes a solution feasible by reassigning jobs
# ----------------------------------------------------------------------
def repair(x):
    """
    Try to repair an infeasible assignment.
    Returns a feasible assignment (may not be optimal).
    """
    x = list(x)          # copy
    used = get_usage(x)

    # Already feasible?
    if all(used[i] <= capacity[i] for i in range(m)):
        return x

    overloaded = [i for i in range(m) if used[i] > capacity[i]]
    max_iter = 100
    for _ in range(max_iter):
        if not overloaded:
            break

        # Most overloaded agent
        i = max(overloaded, key=lambda i: used[i] - capacity[i])
        jobs_assigned = [j for j, a in enumerate(x) if a == i+1]
        if not jobs_assigned:
            overloaded.remove(i)
            continue

        # Select job with largest resource consumption from this agent
        job = max(jobs_assigned, key=lambda j: resource[i][j])

        # Find an agent with enough free capacity to take this job
        best_target = None
        best_cap = -1
        for k in range(m):
            if k == i:
                continue
            if used[k] + resource[i][job] <= capacity[k]:
                if capacity[k] - used[k] > best_cap:
                    best_cap = capacity[k] - used[k]
                    best_target = k

        if best_target is not None:
            # Move job
            x[job] = best_target + 1
            used[i] -= resource[i][job]
            used[best_target] += resource[best_target][job]
        else:
            # No target found; remove this job from consideration
            jobs_assigned.remove(job)
            if not jobs_assigned:
                overloaded.remove(i)

        overloaded = [i for i in range(m) if used[i] > capacity[i]]

    # Final check – if still infeasible, return the original (will be heavily penalized)
    if all(used[i] <= capacity[i] for i in range(m)):
        return x
    else:
        return x

# ----------------------------------------------------------------------
# Fitness function (penalty only for residual infeasibility)
# ----------------------------------------------------------------------
def fitness(x):
    profit = 0.0
    used = [0] * m
    for j, agent in enumerate(x):
        agent_idx = agent - 1
        profit += cost[agent_idx][j]
        used[agent_idx] += resource[agent_idx][j]
    penalty = 0.0
    for i in range(m):
        if used[i] > capacity[i]:
            penalty += (used[i] - capacity[i])
    return profit - lambda_penalty * penalty

# ----------------------------------------------------------------------
# Differential Evolution with repair
# ----------------------------------------------------------------------
def de(seed=None):
    if seed is not None:
        random.seed(seed)

    # Initialise population with feasible solutions
    pop = []
    for _ in range(Np):
        x = [random.randint(1, m) for _ in range(n)]
        x = repair(x)
        pop.append(x)
    fit = [fitness(x) for x in pop]

    best_idx = np.argmax(fit)
    best_x = pop[best_idx][:]
    best_fit = fit[best_idx]

    history = []   # store best profit (actual, no penalty) per generation

    for gen in range(T):
        trial = []
        for i in range(Np):
            # Mutation (DE/rand/1)
            indices = list(range(Np))
            indices.remove(i)
            r1, r2, r3 = random.sample(indices, 3)
            v = []
            for j in range(n):
                val = pop[r1][j] + F * (pop[r2][j] - pop[r3][j])
                vj = int(round(val))
                if vj < 1:
                    vj = 1
                if vj > m:
                    vj = m
                v.append(vj)

            # Crossover
            delta = random.randint(0, n-1)
            u = []
            for j in range(n):
                if random.random() <= pc or j == delta:
                    u.append(v[j])
                else:
                    u.append(pop[i][j])
            u = repair(u)
            trial.append(u)

        # Selection
        for i in range(Np):
            fit_u = fitness(trial[i])
            if fit_u >= fit[i]:
                pop[i] = trial[i]
                fit[i] = fit_u
                if fit_u > best_fit:
                    best_fit = fit_u
                    best_x = trial[i][:]

        # Record actual profit of the current best solution (no penalty)
        best_profit = sum(cost[best_x[j]-1][j] for j in range(n))
        history.append(best_profit)

    final_profit = sum(cost[best_x[j]-1][j] for j in range(n))
    return final_profit, history

# ----------------------------------------------------------------------
# Run the algorithm 20 times
# ----------------------------------------------------------------------
num_runs = 20
profits = []
times = []
convergence_histories = []   # list of profit histories for each run

for run in range(num_runs):
    start = time.perf_counter()
    profit, hist = de(seed=run)   # different seed each run
    end = time.perf_counter()
    profits.append(profit)
    times.append(end - start)
    convergence_histories.append(hist)
    print(f"Run {run+1}: Profit = {profit:.2f}, Time = {end-start:.2f} s")

# Summary statistics
avg_profit = np.mean(profits)
std_profit = np.std(profits)
best_profit = max(profits)
worst_profit = min(profits)
avg_time = np.mean(times)
total_time = np.sum(times)

print("\n=== Summary over {} runs ===".format(num_runs))
print(f"Average profit    : {avg_profit:.2f} ± {std_profit:.2f}")
print(f"Best profit       : {best_profit:.2f}")
print(f"Worst profit      : {worst_profit:.2f}")
print(f"Average time      : {avg_time:.2f} s")
print(f"Total time        : {total_time:.2f} s")

# ----------------------------------------------------------------------
# Convergence plot: all 20 runs + average
# ----------------------------------------------------------------------
plt.figure(figsize=(12, 7))

# Plot each run with low opacity (thin lines)
for i, hist in enumerate(convergence_histories):
    plt.plot(range(1, T+1), hist, 'b-', linewidth=0.5, alpha=0.3)

# Plot the average curve (thick, high contrast)
avg_history = np.mean(convergence_histories, axis=0)
plt.plot(range(1, T+1), avg_history, 'r-', linewidth=3, label='Average over 20 runs')

plt.xlabel('Generation')
plt.ylabel('Best Profit')
plt.title('Convergence of Differential Evolution')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Run 1: Profit = 1449.00, Time = 185.08 s
# Run 2: Profit = 1448.00, Time = 186.02 s
# Run 3: Profit = 1448.00, Time = 184.46 s
# Run 4: Profit = 1449.00, Time = 184.57 s
# Run 5: Profit = 1449.00, Time = 176.85 s
# Run 6: Profit = 1448.00, Time = 178.88 s
# Run 7: Profit = 1449.00, Time = 177.97 s
# Run 8: Profit = 1448.00, Time = 175.46 s
# Run 9: Profit = 1449.00, Time = 179.01 s
# Run 10: Profit = 1447.00, Time = 182.13 s
# Run 11: Profit = 1448.00, Time = 178.96 s
# Run 12: Profit = 1449.00, Time = 180.52 s
# Run 13: Profit = 1450.00, Time = 178.21 s
# Run 14: Profit = 1450.00, Time = 181.37 s
# Run 15: Profit = 1449.00, Time = 178.46 s
# Run 16: Profit = 1449.00, Time = 183.34 s
# Run 17: Profit = 1448.00, Time = 178.04 s
# Run 18: Profit = 1447.00, Time = 178.03 s
# Run 19: Profit = 1448.00, Time = 182.95 s
# Run 20: Profit = 1449.00, Time = 179.92 s
#
# === Summary over 20 runs ===
# Average profit    : 1448.55 ± 0.80
# Best profit       : 1450.00
# Worst profit      : 1447.00
# Average time      : 180.51 s
# Total time        : 3610.23 s

# %%
#GAP-8, Optimal-1133

cost = [
    [21, 25, 18, 18, 21, 25, 22, 18, 18, 23, 17, 24, 16, 21, 24, 20, 23, 24, 23, 24, 19,
     24, 21, 20, 25, 24, 22, 23, 18, 25, 20, 17, 17, 20, 17, 17, 23, 19, 18, 15, 19, 24,
     24, 25, 16, 23, 17, 18],
    [19, 16, 22, 23, 24, 21, 18, 18, 17, 17, 25, 21, 24, 17, 17, 22, 15, 24, 18, 21, 21,
     23, 19, 24, 19, 22, 17, 18, 24, 24, 21, 24, 16, 21, 23, 22, 19, 20, 24, 20, 19, 21,
     24, 25, 22, 15, 19, 16],
    [23, 19, 16, 20, 20, 18, 24, 15, 24, 17, 24, 21, 15, 19, 22, 20, 20, 24, 20, 16, 17,
     19, 18, 18, 17, 24, 23, 15, 16, 22, 25, 24, 22, 16, 25, 20, 16, 20, 18, 15, 24, 24,
     15, 24, 23, 24, 18, 25],
     12, 9, 10, 7, 10, 13],
    [16, 15, 14, 10, 8, 14, 8, 11, 11, 8, 11, 8, 16, 8, 12, 8, 16, 12, 15, 12, 6,
     9, 11, 5, 5, 8, 16, 16, 7, 14, 11, 7, 11, 14, 15, 8, 13, 14, 11, 7, 12, 16,
     6, 12, 8, 15, 11, 14],
    [12, 13, 7, 14, 7, 10, 5, 7, 8, 5, 8, 9, 10, 16, 6, 5, 9, 5, 15, 12, 7,
     13, 10, 16, 9, 10, 16, 5, 16, 11, 7, 10, 16, 8, 15, 6, 10, 12, 12, 7, 7, 13,
     5, 11, 15, 8, 10, 6]
]

capacity = [48, 53, 52, 52, 48, 50, 53, 47]

# %%
import numpy as np
import random
import time
import matplotlib.pyplot as plt

# ----------------------------------------------------------------------
# Parameters
# ----------------------------------------------------------------------
m = len(cost)          # number of agents 
n = len(cost[0])       # number of jobs 
Np = 200               # population size
T = 2000               # number of generations
F = 0.95               # scaling factor
pc = 0.1               # crossover probability
lambda_penalty = 1e9   # very high penalty (repair ensures feasibility)

# ----------------------------------------------------------------------
# Helper: compute resource usage per agent
# ----------------------------------------------------------------------
def get_usage(x):
    used = [0] * m
    for j, agent in enumerate(x):
        agent_idx = agent - 1
        used[agent_idx] += resource[agent_idx][j]
    return used

# ----------------------------------------------------------------------
# Repair function: makes a solution feasible by reassigning jobs
# ----------------------------------------------------------------------
def repair(x):
    """
    Try to repair an infeasible assignment.
    Returns a feasible assignment (may not be optimal).
    """
    x = list(x)          # copy
    used = get_usage(x)

    # Already feasible?
    if all(used[i] <= capacity[i] for i in range(m)):
        return x

    overloaded = [i for i in range(m) if used[i] > capacity[i]]
    max_iter = 100
    for _ in range(max_iter):
        if not overloaded:
            break

        # Most overloaded agent
        i = max(overloaded, key=lambda i: used[i] - capacity[i])
        jobs_assigned = [j for j, a in enumerate(x) if a == i+1]
        if not jobs_assigned:
            overloaded.remove(i)
            continue

        # Select job with largest resource consumption from this agent
        job = max(jobs_assigned, key=lambda j: resource[i][j])

        # Find an agent with enough free capacity to take this job
        best_target = None
        best_cap = -1
        for k in range(m):
            if k == i:
                continue
            if used[k] + resource[i][job] <= capacity[k]:
                if capacity[k] - used[k] > best_cap:
                    best_cap = capacity[k] - used[k]
                    best_target = k

        if best_target is not None:
            # Move job
            x[job] = best_target + 1
            used[i] -= resource[i][job]
            used[best_target] += resource[best_target][job]
        else:
            # No target found; remove this job from consideration
            jobs_assigned.remove(job)
            if not jobs_assigned:
                overloaded.remove(i)

        overloaded = [i for i in range(m) if used[i] > capacity[i]]

    # Final check – if still infeasible, return the original (will be heavily penalized)
    if all(used[i] <= capacity[i] for i in range(m)):
        return x
    else:
        return x

# ----------------------------------------------------------------------
# Fitness function (penalty only for residual infeasibility)
# ----------------------------------------------------------------------
def fitness(x):
    profit = 0.0
    used = [0] * m
    for j, agent in enumerate(x):
        agent_idx = agent - 1
        profit += cost[agent_idx][j]
        used[agent_idx] += resource[agent_idx][j]
    penalty = 0.0
    for i in range(m):
        if used[i] > capacity[i]:
            penalty += (used[i] - capacity[i])
    return profit - lambda_penalty * penalty

# ----------------------------------------------------------------------
# Differential Evolution with repair
# ----------------------------------------------------------------------
def de(seed=None):
    if seed is not None:
        random.seed(seed)

    # Initialise population with feasible solutions
    pop = []
    for _ in range(Np):
        x = [random.randint(1, m) for _ in range(n)]
        x = repair(x)
        pop.append(x)
    fit = [fitness(x) for x in pop]

    best_idx = np.argmax(fit)
    best_x = pop[best_idx][:]
    best_fit = fit[best_idx]

    history = []   # store best profit (actual, no penalty) per generation

    for gen in range(T):
        trial = []
        for i in range(Np):
            # Mutation (DE/rand/1)
            indices = list(range(Np))
            indices.remove(i)
            r1, r2, r3 = random.sample(indices, 3)
            v = []
            for j in range(n):
                val = pop[r1][j] + F * (pop[r2][j] - pop[r3][j])
                vj = int(round(val))
                if vj < 1:
                    vj = 1
                if vj > m:
                    vj = m
                v.append(vj)

            # Crossover
            delta = random.randint(0, n-1)
            u = []
            for j in range(n):
                if random.random() <= pc or j == delta:
                    u.append(v[j])
                else:
                    u.append(pop[i][j])
            u = repair(u)
            trial.append(u)

        # Selection
        for i in range(Np):
            fit_u = fitness(trial[i])
            if fit_u >= fit[i]:
                pop[i] = trial[i]
                fit[i] = fit_u
                if fit_u > best_fit:
                    best_fit = fit_u
                    best_x = trial[i][:]

        # Record actual profit of the current best solution (no penalty)
        best_profit = sum(cost[best_x[j]-1][j] for j in range(n))
        history.append(best_profit)

    final_profit = sum(cost[best_x[j]-1][j] for j in range(n))
    return final_profit, history

# ----------------------------------------------------------------------
# Run the algorithm 20 times
# ----------------------------------------------------------------------
num_runs = 20
profits = []
times = []
convergence_histories = []   # list of profit histories for each run

for run in range(num_runs):
    start = time.perf_counter()
    profit, hist = de(seed=run)   # different seed each run
    end = time.perf_counter()
    profits.append(profit)
    times.append(end - start)
    convergence_histories.append(hist)
    print(f"Run {run+1}: Profit = {profit:.2f}, Time = {end-start:.2f} s")

# Summary statistics
avg_profit = np.mean(profits)
std_profit = np.std(profits)
best_profit = max(profits)
worst_profit = min(profits)
avg_time = np.mean(times)
total_time = np.sum(times)

print("\n=== Summary over {} runs ===".format(num_runs))
print(f"Average profit    : {avg_profit:.2f} ± {std_profit:.2f}")
print(f"Best profit       : {best_profit:.2f}")
print(f"Worst profit      : {worst_profit:.2f}")
print(f"Average time      : {avg_time:.2f} s")
print(f"Total time        : {total_time:.2f} s")

# ----------------------------------------------------------------------
# Convergence plot: all 20 runs + average
# ----------------------------------------------------------------------
plt.figure(figsize=(12, 7))

# Plot each run with low opacity (thin lines)
for i, hist in enumerate(convergence_histories):
    plt.plot(range(1, T+1), hist, 'b-', linewidth=0.5, alpha=0.3)

# Plot the average curve (thick, high contrast)
avg_history = np.mean(convergence_histories, axis=0)
plt.plot(range(1, T+1), avg_history, 'r-', linewidth=3, label='Average over 20 runs')

plt.xlabel('Generation')
plt.ylabel('Best Profit')
plt.title('Convergence of Differential Evolution')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Run 1: Profit = 1125.00, Time = 177.25 s
# Run 2: Profit = 1123.00, Time = 177.66 s
# Run 3: Profit = 1123.00, Time = 169.14 s
# Run 4: Profit = 1124.00, Time = 182.42 s
# Run 5: Profit = 1122.00, Time = 174.71 s
# Run 6: Profit = 1125.00, Time = 172.85 s
# Run 7: Profit = 1125.00, Time = 169.87 s
# Run 8: Profit = 1123.00, Time = 192.01 s
# Run 9: Profit = 1124.00, Time = 171.86 s
# Run 10: Profit = 1125.00, Time = 172.85 s
# Run 11: Profit = 1123.00, Time = 175.67 s
# Run 12: Profit = 1128.00, Time = 173.17 s
# Run 13: Profit = 1122.00, Time = 177.68 s
# Run 14: Profit = 1125.00, Time = 182.25 s
# Run 15: Profit = 1125.00, Time = 183.24 s
# Run 16: Profit = 1124.00, Time = 227.44 s
# Run 17: Profit = 1125.00, Time = 232.93 s
# Run 18: Profit = 1125.00, Time = 249.33 s
# Run 19: Profit = 1125.00, Time = 249.59 s
# Run 20: Profit = 1124.00, Time = 226.25 s
#
# === Summary over 20 runs ===
# Average profit    : 1124.25 ± 1.34
# Best profit       : 1128.00
# Worst profit      : 1122.00
# Average time      : 191.91 s
# Total time        : 3838.18 s

# %%
#GAP-10, Optimal-958

cost = [
    [17, 21, 25, 19, 24, 22, 24, 20, 23, 15, 16, 17, 23, 21, 20, 21, 22, 19, 24, 22, 16,
     23, 24, 16, 24, 15, 17, 17, 19, 19, 25, 18, 21, 15, 21, 23, 18, 21, 19, 16],
    [16, 16, 18, 15, 16, 22, 20, 24, 25, 23, 20, 25, 15, 16, 22, 19, 22, 16, 23, 18, 21,
     24, 22, 22, 17, 25, 15, 24, 16, 16, 18, 20, 15, 15, 16, 24, 16, 20, 17, 21],
    [25, 24, 24, 18, 20, 19, 25, 17, 19, 19, 22, 18, 19, 19, 24, 22, 22, 20, 16, 25, 19,
     25, 19, 21, 20, 24, 20, 20, 15, 24, 23, 23, 17, 15, 24, 20, 23, 19, 19, 22],
    [21, 18, 19, 21, 23, 15, 17, 19, 25, 25, 15, 20, 18, 18, 15, 21, 22, 16, 25, 17, 17,
     16, 15, 17, 24, 25, 24, 22, 23, 24, 20, 17, 20, 16, 24, 18, 21, 22, 20, 16],
    [23, 22, 15, 17, 25, 25, 24, 20, 21, 23, 17, 23, 21, 18, 18, 22, 18, 15, 15, 21, 19,
     24, 16, 19, 20, 16, 23, 17, 15, 24, 15, 24, 19, 21, 17, 16, 16, 22, 16, 24],
    [19, 17, 19, 24, 25, 23, 19, 15, 22, 23, 15, 22, 19, 19, 17, 16, 22, 19, 20, 22, 25,
     15, 24, 24, 24, 22, 22, 19, 21, 23, 24, 17, 23, 17, 20, 22, 20, 25, 19, 20],
    [17, 25, 23, 21, 21, 16, 18, 19, 20, 19, 17, 21, 23, 16, 19, 23, 23, 18, 24, 15, 19,
     22, 25, 21, 19, 17, 25, 18, 22, 21, 16, 15, 20, 15, 19, 24, 25, 18, 15, 21],
    [15, 23, 18, 15, 24, 18, 16, 24, 25, 24, 17, 25, 21, 22, 22, 18, 20, 16, 16, 23, 23,
     23, 15, 24, 20, 20, 18, 25, 16, 22, 20, 23, 15, 17, 19, 16, 18, 16, 16, 23],
    [18, 23, 24, 21, 18, 16, 18, 24, 16, 21, 21, 23, 25, 17, 19, 20, 17, 15, 23, 16, 24,
# %%
import numpy as np
import random
import time
import matplotlib.pyplot as plt

# ----------------------------------------------------------------------
# Parameters
# ----------------------------------------------------------------------
m = len(cost)          # number of agents 
n = len(cost[0])       # number of jobs 
Np = 200               # population size
T = 1500               # number of generations
F = 0.95               # scaling factor
pc = 0.1               # crossover probability
lambda_penalty = 1e9   # very high penalty (repair ensures feasibility)

# ----------------------------------------------------------------------
# Helper: compute resource usage per agent
# ----------------------------------------------------------------------
def get_usage(x):
    used = [0] * m
    for j, agent in enumerate(x):
        agent_idx = agent - 1
        used[agent_idx] += resource[agent_idx][j]
    return used

# ----------------------------------------------------------------------
# Repair function: makes a solution feasible by reassigning jobs
# ----------------------------------------------------------------------
def repair(x):
    """
    Try to repair an infeasible assignment.
    Returns a feasible assignment (may not be optimal).
    """
    x = list(x)          # copy
    used = get_usage(x)

    # Already feasible?
    if all(used[i] <= capacity[i] for i in range(m)):
        return x

    overloaded = [i for i in range(m) if used[i] > capacity[i]]
    max_iter = 100
    for _ in range(max_iter):
        if not overloaded:
            break

        # Most overloaded agent
        i = max(overloaded, key=lambda i: used[i] - capacity[i])
        jobs_assigned = [j for j, a in enumerate(x) if a == i+1]
        if not jobs_assigned:
            overloaded.remove(i)
            continue

        # Select job with largest resource consumption from this agent
        job = max(jobs_assigned, key=lambda j: resource[i][j])

        # Find an agent with enough free capacity to take this job
        best_target = None
        best_cap = -1
        for k in range(m):
            if k == i:
                continue
            if used[k] + resource[i][job] <= capacity[k]:
                if capacity[k] - used[k] > best_cap:
                    best_cap = capacity[k] - used[k]
                    best_target = k

        if best_target is not None:
            # Move job
            x[job] = best_target + 1
            used[i] -= resource[i][job]
            used[best_target] += resource[best_target][job]
        else:
            # No target found; remove this job from consideration
            jobs_assigned.remove(job)
            if not jobs_assigned:
                overloaded.remove(i)

        overloaded = [i for i in range(m) if used[i] > capacity[i]]

    # Final check – if still infeasible, return the original (will be heavily penalized)
    if all(used[i] <= capacity[i] for i in range(m)):
        return x
    else:
        return x

# ----------------------------------------------------------------------
# Fitness function (penalty only for residual infeasibility)
# ----------------------------------------------------------------------
def fitness(x):
    profit = 0.0
    used = [0] * m
    for j, agent in enumerate(x):
        agent_idx = agent - 1
        profit += cost[agent_idx][j]
        used[agent_idx] += resource[agent_idx][j]
    penalty = 0.0
    for i in range(m):
        if used[i] > capacity[i]:
            penalty += (used[i] - capacity[i])
    return profit - lambda_penalty * penalty

# ----------------------------------------------------------------------
# Differential Evolution with repair
# ----------------------------------------------------------------------
def de(seed=None):
    if seed is not None:
        random.seed(seed)

    # Initialise population with feasible solutions
    pop = []
    for _ in range(Np):
        x = [random.randint(1, m) for _ in range(n)]
        x = repair(x)
        pop.append(x)
    fit = [fitness(x) for x in pop]

    best_idx = np.argmax(fit)
    best_x = pop[best_idx][:]
    best_fit = fit[best_idx]

    history = []   # store best profit (actual, no penalty) per generation

    for gen in range(T):
        trial = []
        for i in range(Np):
            # Mutation (DE/rand/1)
            indices = list(range(Np))
            indices.remove(i)
            r1, r2, r3 = random.sample(indices, 3)
            v = []
            for j in range(n):
                val = pop[r1][j] + F * (pop[r2][j] - pop[r3][j])
                vj = int(round(val))
                if vj < 1:
                    vj = 1
                if vj > m:
                    vj = m
                v.append(vj)

            # Crossover
            delta = random.randint(0, n-1)
            u = []
            for j in range(n):
                if random.random() <= pc or j == delta:
                    u.append(v[j])
                else:
                    u.append(pop[i][j])
            u = repair(u)
            trial.append(u)

        # Selection
        for i in range(Np):
            fit_u = fitness(trial[i])
            if fit_u >= fit[i]:
                pop[i] = trial[i]
                fit[i] = fit_u
                if fit_u > best_fit:
                    best_fit = fit_u
                    best_x = trial[i][:]

        # Record actual profit of the current best solution (no penalty)
        best_profit = sum(cost[best_x[j]-1][j] for j in range(n))
        history.append(best_profit)

    final_profit = sum(cost[best_x[j]-1][j] for j in range(n))
    return final_profit, history

# ----------------------------------------------------------------------
# Run the algorithm 20 times
# ----------------------------------------------------------------------
num_runs = 20
profits = []
times = []
convergence_histories = []   # list of profit histories for each run

for run in range(num_runs):
    start = time.perf_counter()
    profit, hist = de(seed=run)   # different seed each run
    end = time.perf_counter()
    profits.append(profit)
    times.append(end - start)
    convergence_histories.append(hist)
    print(f"Run {run+1}: Profit = {profit:.2f}, Time = {end-start:.2f} s")

# Summary statistics
avg_profit = np.mean(profits)
std_profit = np.std(profits)
best_profit = max(profits)
worst_profit = min(profits)
avg_time = np.mean(times)
total_time = np.sum(times)

print("\n=== Summary over {} runs ===".format(num_runs))
print(f"Average profit    : {avg_profit:.2f} ± {std_profit:.2f}")
print(f"Best profit       : {best_profit:.2f}")
print(f"Worst profit      : {worst_profit:.2f}")
print(f"Average time      : {avg_time:.2f} s")
print(f"Total time        : {total_time:.2f} s")

# ----------------------------------------------------------------------
# Convergence plot: all 20 runs + average
# ----------------------------------------------------------------------
plt.figure(figsize=(12, 7))

# Plot each run with low opacity (thin lines)
for i, hist in enumerate(convergence_histories):
    plt.plot(range(1, T+1), hist, 'b-', linewidth=0.5, alpha=0.3)

# Plot the average curve (thick, high contrast)
avg_history = np.mean(convergence_histories, axis=0)
plt.plot(range(1, T+1), avg_history, 'r-', linewidth=3, label='Average over 20 runs')

plt.xlabel('Generation')
plt.ylabel('Best Profit')
plt.title('Convergence of Differential Evolution')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Run 1: Profit = 956.00, Time = 91.29 s
# Run 2: Profit = 956.00, Time = 89.24 s
# Run 3: Profit = 956.00, Time = 84.76 s
# Run 4: Profit = 956.00, Time = 88.52 s
# Run 5: Profit = 956.00, Time = 100.05 s
# Run 6: Profit = 956.00, Time = 109.69 s
# Run 7: Profit = 956.00, Time = 104.73 s
# Run 8: Profit = 956.00, Time = 87.68 s
# Run 9: Profit = 956.00, Time = 94.52 s
# Run 10: Profit = 956.00, Time = 84.98 s
# Run 11: Profit = 956.00, Time = 84.90 s
# Run 12: Profit = 956.00, Time = 88.96 s
# Run 13: Profit = 956.00, Time = 89.28 s
# Run 14: Profit = 955.00, Time = 86.69 s
# Run 15: Profit = 956.00, Time = 91.91 s
# Run 16: Profit = 956.00, Time = 85.57 s
# Run 17: Profit = 957.00, Time = 90.03 s
# Run 18: Profit = 956.00, Time = 87.27 s
# Run 19: Profit = 956.00, Time = 90.85 s
# Run 20: Profit = 956.00, Time = 87.60 s
#
# === Summary over 20 runs ===
# Average profit    : 956.00 ± 0.32
# Best profit       : 957.00
# Worst profit      : 955.00
# Average time      : 90.93 s
# Total time        : 1818.52 s
