    [22,14,19,7,5,20,19,5,20,7,12,8,13,18,16,9,23,16,16,9,25,8,13,16,6,8,5,18,12,5,12,16,12,25,5,24,23,23,25,22,17,17,21,24,16,7,17,9,13,24,22,25,25,23,12,12,8,24,14,8],
    [17,10,18,13,14,18,6,6,11,9,12,20,15,12,18,18,11,7,9,25,13,9,10,9,15,10,19,15,15,14,25,6,12,21,9,10,18,20,13,17,17,21,15,9,22,11,14,14,13,16,12,5,14,18,24,9,19,14,9,24],
    [24,23,6,13,9,17,18,21,10,15,15,18,14,15,11,24,20,24,16,20,23,25,9,21,21,13,9,24,12,8,14,21,16,25,20,23,8,16,20,10,5,16,11,20,10,11,21,15,12,12,21,10,19,18,10,25,23,16,8,25],
    [5,21,24,13,21,11,18,12,24,22,20,21,16,18,8,25,7,19,11,12,18,5,15,7,12,5,23,16,12,5,8,24,25,10,13,24,22,20,12,16,18,9,21,17,19,6,21,12,6,9,24,10,8,13,13,13,23,25,8,22],
    [9,19,23,7,5,8,16,17,21,15,15,12,21,24,15,6,7,11,5,13,10,16,19,9,22,8,21,17,7,8,25,23,20,8,14,16,5,16,5,10,17,6,18,9,19,9,11,18,23,14,24,13,20,10,22,19,6,15,18,15],
    [23,15,16,20,19,23,8,15,24,25,25,5,13,14,12,25,5,11,23,24,18,7,17,10,25,21,13,19,18,6,8,9,21,18,5,12,8,7,19,24,7,9,22,7,9,10,14,24,22,24,15,16,11,19,18,18,16,8,6,8],
    [10,14,24,13,18,11,13,24,22,7,12,17,23,12,15,5,5,16,20,22,18,12,20,12,9,5,7,6,25,6,7,13,7,23,21,21,18,8,23,7,11,9,15,19,9,13,22,24,18,14,11,15,15,18,22,13,17,14,11,11]
]

capacity = [79, 67, 74, 73, 67, 78, 73, 68, 73, 69]

# %%
import random
import numpy as np
import time
import matplotlib.pyplot as plt

NUM_AGENTS = 10
NUM_JOBS = 60
LAMBDA = 1_000_000   # penalty coefficient

def evaluate(solution):
    """Return profit - LAMBDA * total resource violation."""
    profit = 0
    used = [0] * NUM_AGENTS
    for job, agent in enumerate(solution):
        profit += cost[agent][job]
        used[agent] += resource[agent][job]
    violation = sum(max(0, used[i] - capacity[i]) for i in range(NUM_AGENTS))
    return profit - LAMBDA * violation

def true_profit_and_feasibility(solution):
    """Return (profit, feasible_flag) without penalty."""
    profit = 0
    used = [0] * NUM_AGENTS
    for job, agent in enumerate(solution):
        profit += cost[agent][job]
        used[agent] += resource[agent][job]
    feasible = all(used[i] <= capacity[i] for i in range(NUM_AGENTS))
    return profit, feasible

def generate_neighbour(source, partner):
    """Discrete neighbour: copy partner or random agent for one job."""
    new_sol = source.copy()
    job = random.randint(0, NUM_JOBS - 1)
    if random.random() < 0.5:
        new_sol[job] = partner[job]
    else:
        new_sol[job] = random.randint(0, NUM_AGENTS - 1)
    return new_sol

def abc_gap(Np, T, limit, seed=None):
    """Run ABC and return (best_solution, best_true_profit, convergence_history)."""
    if seed is not None:
        random.seed(seed)
        np.random.seed(seed)

    # Initialisation
    population = []
    fitness = []
    trial = []
    for _ in range(Np):
        sol = [random.randint(0, NUM_AGENTS - 1) for _ in range(NUM_JOBS)]
        fit = evaluate(sol)
        population.append(sol)
        fitness.append(fit)
        trial.append(0)

    # Best tracking
    best_idx = np.argmax(fitness)
    best_sol = population[best_idx].copy()
    best_true_profit, _ = true_profit_and_feasibility(best_sol)
    history = []   # best true profit per generation

    for gen in range(T):
        # Employed Bee Phase
        for i in range(Np):
            partner = random.choice([p for p in range(Np) if p != i])
            new_sol = generate_neighbour(population[i], population[partner])
            new_fit = evaluate(new_sol)
            if new_fit > fitness[i]:
                population[i] = new_sol
                fitness[i] = new_fit
                trial[i] = 0
            else:
                trial[i] += 1

        # Probability calculation (shift if necessary)
        total_fit = sum(fitness)
        if total_fit <= 0:
            shift = -total_fit + 1e-6
            prob = [(f + shift) / (total_fit + shift * Np) for f in fitness]
        else:
            prob = [f / total_fit for f in fitness]

        # Onlooker Bee Phase
        m = 0
        n = 0
        while m < Np:
            if random.random() < prob[n]:
                partner = random.choice([p for p in range(Np) if p != n])
                new_sol = generate_neighbour(population[n], population[partner])
                new_fit = evaluate(new_sol)
                if new_fit > fitness[n]:
                    population[n] = new_sol
                    fitness[n] = new_fit
                    trial[n] = 0
                else:
                    trial[n] += 1
                m += 1
            n = (n + 1) % Np

        # Scout Bee Phase
        for i in range(Np):
            if trial[i] > limit:
                new_sol = [random.randint(0, NUM_AGENTS - 1) for _ in range(NUM_JOBS)]
                new_fit = evaluate(new_sol)
                population[i] = new_sol
                fitness[i] = new_fit
                trial[i] = 0

        # Update best solution
        current_best_idx = np.argmax(fitness)
        current_best_sol = population[current_best_idx]
        current_true_profit, _ = true_profit_and_feasibility(current_best_sol)
        if current_true_profit > best_true_profit:
            best_true_profit = current_true_profit
            best_sol = current_best_sol.copy()
        history.append(best_true_profit)

    return best_sol, best_true_profit, history

# ------------------------------------------------------------
# Main: run 20 times, collect statistics, plot convergence
# ------------------------------------------------------------

def main():
    NUM_RUNS = 20
    results = []
    all_histories = []   # store history of each run
    best_profit_overall = -float('inf')
    best_solution_overall = None
    best_run_history = None

    print("Running ABC 20 times...\n")
    for run in range(1, NUM_RUNS + 1):
        start_time = time.time()
        sol, profit, history = abc_gap(Np=100, T=700, limit=100, seed=run)
        elapsed = time.time() - start_time
        _, feasible = true_profit_and_feasibility(sol)
        results.append((profit, elapsed, feasible))
        all_histories.append(history)
        if profit > best_profit_overall:
            best_profit_overall = profit
            best_solution_overall = sol
            best_run_history = history
        print(f"Run {run:2d}: Profit = {profit:.2f}, Time = {elapsed:.2f} s, Feasible = {feasible}")

    # Summary statistics
    profits = [r[0] for r in results]
    times = [r[1] for r in results]
    feasible_count = sum(1 for r in results if r[2])
    avg_profit = np.mean(profits)
    std_profit = np.std(profits)
    best_profit = max(profits)
    worst_profit = min(profits)
    avg_time = np.mean(times)
    total_time = sum(times)

    print("\n=== Summary over {} runs ===".format(NUM_RUNS))
    print(f"Average profit    : {avg_profit:.2f} ± {std_profit:.2f}")
    print(f"Best profit       : {best_profit:.2f}")
    print(f"Worst profit      : {worst_profit:.2f}")
    print(f"Feasible runs     : {feasible_count}/{NUM_RUNS}")
    print(f"Average time      : {avg_time:.2f} s")
    print(f"Total time        : {total_time:.2f} s")

    # --- NEW PLOT: all 20 runs + average ---
    plt.figure(figsize=(12, 6))
    generations = range(700)   # T = 700

    # Plot each run with low opacity
    for hist in all_histories:
        plt.plot(generations, hist, color='blue', alpha=0.2, linewidth=0.8)

    # Compute and plot average convergence
    avg_history = np.mean(all_histories, axis=0)
    plt.plot(generations, avg_history, color='red', linewidth=2.5, label='Average (20 runs)')

    plt.xlabel('Generation', fontsize=12)
    plt.ylabel('Best True Profit', fontsize=12)
    plt.title('Convergence of ABC over 20 Runs', fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.savefig('abc_all_runs_convergence.png', dpi=150)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Running ABC 20 times...
#
# Run  1: Profit = 1425.00, Time = 3.07 s, Feasible = True
# Run  2: Profit = 1426.00, Time = 3.06 s, Feasible = True
# Run  3: Profit = 1428.00, Time = 3.04 s, Feasible = True
# Run  4: Profit = 1426.00, Time = 3.04 s, Feasible = True
# Run  5: Profit = 1419.00, Time = 3.06 s, Feasible = True
# Run  6: Profit = 1421.00, Time = 3.06 s, Feasible = True
# Run  7: Profit = 1422.00, Time = 3.10 s, Feasible = True
# Run  8: Profit = 1426.00, Time = 3.08 s, Feasible = True
# Run  9: Profit = 1427.00, Time = 3.06 s, Feasible = True
# Run 10: Profit = 1428.00, Time = 3.10 s, Feasible = True
# Run 11: Profit = 1426.00, Time = 3.09 s, Feasible = True
# Run 12: Profit = 1420.00, Time = 3.09 s, Feasible = True
# Run 13: Profit = 1420.00, Time = 3.11 s, Feasible = True
# Run 14: Profit = 1423.00, Time = 3.06 s, Feasible = True
# Run 15: Profit = 1432.00, Time = 3.11 s, Feasible = True
# Run 16: Profit = 1423.00, Time = 3.06 s, Feasible = True
# Run 17: Profit = 1420.00, Time = 3.09 s, Feasible = True
# Run 18: Profit = 1427.00, Time = 3.08 s, Feasible = True
# Run 19: Profit = 1421.00, Time = 3.23 s, Feasible = True
# Run 20: Profit = 1425.00, Time = 3.07 s, Feasible = True
#
# === Summary over 20 runs ===
# Average profit    : 1424.25 ± 3.37
# Best profit       : 1432.00
# Worst profit      : 1419.00
# Feasible runs     : 20/20
# Average time      : 3.08 s
# Total time        : 61.66 s

# %%
#GAP-8, Optimal-1133

cost = [
    [21, 25, 18, 18, 21, 25, 22, 18, 18, 23, 17, 24, 16, 21, 24, 20, 23, 24, 23, 24, 19,
     24, 21, 20, 25, 24, 22, 23, 18, 25, 20, 17, 17, 20, 17, 17, 23, 19, 18, 15, 19, 24,
     24, 25, 16, 23, 17, 18],
    [19, 16, 22, 23, 24, 21, 18, 18, 17, 17, 25, 21, 24, 17, 17, 22, 15, 24, 18, 21, 21,
     23, 19, 24, 19, 22, 17, 18, 24, 24, 21, 24, 16, 21, 23, 22, 19, 20, 24, 20, 19, 21,
     24, 25, 22, 15, 19, 16],
    [23, 19, 16, 20, 20, 18, 24, 15, 24, 17, 24, 21, 15, 19, 22, 20, 20, 24, 20, 16, 17,
     19, 18, 18, 17, 24, 23, 15, 16, 22, 25, 24, 22, 16, 25, 20, 16, 20, 18, 15, 24, 24,
     15, 24, 23, 24, 18, 25],
     12, 9, 10, 7, 10, 13],
    [16, 15, 14, 10, 8, 14, 8, 11, 11, 8, 11, 8, 16, 8, 12, 8, 16, 12, 15, 12, 6,
     9, 11, 5, 5, 8, 16, 16, 7, 14, 11, 7, 11, 14, 15, 8, 13, 14, 11, 7, 12, 16,
     6, 12, 8, 15, 11, 14],
    [12, 13, 7, 14, 7, 10, 5, 7, 8, 5, 8, 9, 10, 16, 6, 5, 9, 5, 15, 12, 7,
     13, 10, 16, 9, 10, 16, 5, 16, 11, 7, 10, 16, 8, 15, 6, 10, 12, 12, 7, 7, 13,
     5, 11, 15, 8, 10, 6]
]

capacity = [48, 53, 52, 52, 48, 50, 53, 47]

# %%
import random
import numpy as np
import time
import matplotlib.pyplot as plt

NUM_AGENTS = 8
NUM_JOBS = 48
LAMBDA = 1_000_000   # penalty coefficient

def evaluate(solution):
    """Return profit - LAMBDA * total resource violation."""
    profit = 0
    used = [0] * NUM_AGENTS
    for job, agent in enumerate(solution):
        profit += cost[agent][job]
        used[agent] += resource[agent][job]
    violation = sum(max(0, used[i] - capacity[i]) for i in range(NUM_AGENTS))
    return profit - LAMBDA * violation

def true_profit_and_feasibility(solution):
    """Return (profit, feasible_flag) without penalty."""
    profit = 0
    used = [0] * NUM_AGENTS
    for job, agent in enumerate(solution):
        profit += cost[agent][job]
        used[agent] += resource[agent][job]
    feasible = all(used[i] <= capacity[i] for i in range(NUM_AGENTS))
    return profit, feasible

def generate_neighbour(source, partner):
    """Discrete neighbour: copy partner or random agent for one job."""
    new_sol = source.copy()
    job = random.randint(0, NUM_JOBS - 1)
    if random.random() < 0.5:
        new_sol[job] = partner[job]
    else:
        new_sol[job] = random.randint(0, NUM_AGENTS - 1)
    return new_sol

def abc_gap(Np, T, limit, seed=None):
    """Run ABC and return (best_solution, best_true_profit, convergence_history)."""
    if seed is not None:
        random.seed(seed)
        np.random.seed(seed)

    # Initialisation
    population = []
    fitness = []
    trial = []
    for _ in range(Np):
        sol = [random.randint(0, NUM_AGENTS - 1) for _ in range(NUM_JOBS)]
        fit = evaluate(sol)
        population.append(sol)
        fitness.append(fit)
        trial.append(0)

    # Best tracking
    best_idx = np.argmax(fitness)
    best_sol = population[best_idx].copy()
    best_true_profit, _ = true_profit_and_feasibility(best_sol)
    history = []   # best true profit per generation

    for gen in range(T):
        # Employed Bee Phase
        for i in range(Np):
            partner = random.choice([p for p in range(Np) if p != i])
            new_sol = generate_neighbour(population[i], population[partner])
            new_fit = evaluate(new_sol)
            if new_fit > fitness[i]:
                population[i] = new_sol
                fitness[i] = new_fit
                trial[i] = 0
            else:
                trial[i] += 1

        # Probability calculation (shift if necessary)
        total_fit = sum(fitness)
        if total_fit <= 0:
            shift = -total_fit + 1e-6
            prob = [(f + shift) / (total_fit + shift * Np) for f in fitness]
        else:
            prob = [f / total_fit for f in fitness]

        # Onlooker Bee Phase
        m = 0
        n = 0
        while m < Np:
            if random.random() < prob[n]:
                partner = random.choice([p for p in range(Np) if p != n])
                new_sol = generate_neighbour(population[n], population[partner])
                new_fit = evaluate(new_sol)
                if new_fit > fitness[n]:
                    population[n] = new_sol
                    fitness[n] = new_fit
                    trial[n] = 0
                else:
                    trial[n] += 1
                m += 1
            n = (n + 1) % Np

        # Scout Bee Phase
        for i in range(Np):
            if trial[i] > limit:
                new_sol = [random.randint(0, NUM_AGENTS - 1) for _ in range(NUM_JOBS)]
                new_fit = evaluate(new_sol)
                population[i] = new_sol
                fitness[i] = new_fit
                trial[i] = 0

        # Update best solution
        current_best_idx = np.argmax(fitness)
        current_best_sol = population[current_best_idx]
        current_true_profit, _ = true_profit_and_feasibility(current_best_sol)
        if current_true_profit > best_true_profit:
            best_true_profit = current_true_profit
            best_sol = current_best_sol.copy()
        history.append(best_true_profit)

    return best_sol, best_true_profit, history

# ------------------------------------------------------------
# Main: run 20 times, collect statistics, plot convergence
# ------------------------------------------------------------

def main():
    NUM_RUNS = 20
    results = []
    all_histories = []   # store history of each run
    best_profit_overall = -float('inf')
    best_solution_overall = None
    best_run_history = None

    print("Running ABC 20 times...\n")
    for run in range(1, NUM_RUNS + 1):
        start_time = time.time()
        sol, profit, history = abc_gap(Np=100, T=700, limit=100, seed=run)
        elapsed = time.time() - start_time
        _, feasible = true_profit_and_feasibility(sol)
        results.append((profit, elapsed, feasible))
        all_histories.append(history)
        if profit > best_profit_overall:
            best_profit_overall = profit
            best_solution_overall = sol
            best_run_history = history
        print(f"Run {run:2d}: Profit = {profit:.2f}, Time = {elapsed:.2f} s, Feasible = {feasible}")

    # Summary statistics
    profits = [r[0] for r in results]
    times = [r[1] for r in results]
    feasible_count = sum(1 for r in results if r[2])
    avg_profit = np.mean(profits)
    std_profit = np.std(profits)
    best_profit = max(profits)
    worst_profit = min(profits)
    avg_time = np.mean(times)
    total_time = sum(times)

    print("\n=== Summary over {} runs ===".format(NUM_RUNS))
    print(f"Average profit    : {avg_profit:.2f} ± {std_profit:.2f}")
    print(f"Best profit       : {best_profit:.2f}")
    print(f"Worst profit      : {worst_profit:.2f}")
    print(f"Feasible runs     : {feasible_count}/{NUM_RUNS}")
    print(f"Average time      : {avg_time:.2f} s")
    print(f"Total time        : {total_time:.2f} s")

    # --- NEW PLOT: all 20 runs + average ---
    plt.figure(figsize=(12, 6))
    generations = range(700)   # T = 700

    # Plot each run with low opacity
    for hist in all_histories:
        plt.plot(generations, hist, color='blue', alpha=0.2, linewidth=0.8)

    # Compute and plot average convergence
    avg_history = np.mean(all_histories, axis=0)
    plt.plot(generations, avg_history, color='red', linewidth=2.5, label='Average (20 runs)')

    plt.xlabel('Generation', fontsize=12)
    plt.ylabel('Best True Profit', fontsize=12)
    plt.title('Convergence of ABC over 20 Runs', fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.savefig('abc_all_runs_convergence.png', dpi=150)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Running ABC 20 times...
#
# Run  1: Profit = 1051.00, Time = 3.72 s, Feasible = True
# Run  2: Profit = 1067.00, Time = 3.59 s, Feasible = True
# Run  3: Profit = 1065.00, Time = 3.70 s, Feasible = True
# Run  4: Profit = 1062.00, Time = 3.89 s, Feasible = True
# Run  5: Profit = 1080.00, Time = 3.43 s, Feasible = True
# Run  6: Profit = 1066.00, Time = 3.65 s, Feasible = True
# Run  7: Profit = 1071.00, Time = 3.64 s, Feasible = True
# Run  8: Profit = 1069.00, Time = 3.86 s, Feasible = True
# Run  9: Profit = 1066.00, Time = 3.48 s, Feasible = True
# Run 10: Profit = 1081.00, Time = 3.81 s, Feasible = True
# Run 11: Profit = 1081.00, Time = 3.52 s, Feasible = True
# Run 12: Profit = 1036.00, Time = 3.77 s, Feasible = True
# Run 13: Profit = 1049.00, Time = 3.77 s, Feasible = True
# Run 14: Profit = 1060.00, Time = 3.46 s, Feasible = True
# Run 15: Profit = 1062.00, Time = 3.50 s, Feasible = True
# Run 16: Profit = 1072.00, Time = 3.73 s, Feasible = True
# Run 17: Profit = 1076.00, Time = 3.60 s, Feasible = True
# Run 18: Profit = 1064.00, Time = 3.49 s, Feasible = True
# Run 19: Profit = 1060.00, Time = 3.75 s, Feasible = True
# Run 20: Profit = 1075.00, Time = 3.69 s, Feasible = True
#
# === Summary over 20 runs ===
# Average profit    : 1065.65 ± 11.00
# Best profit       : 1081.00
# Worst profit      : 1036.00
# Feasible runs     : 20/20
# Average time      : 3.65 s
# Total time        : 73.02 s

# %%
#GAP-10, Optimal-958

cost = [
    [17, 21, 25, 19, 24, 22, 24, 20, 23, 15, 16, 17, 23, 21, 20, 21, 22, 19, 24, 22, 16,
     23, 24, 16, 24, 15, 17, 17, 19, 19, 25, 18, 21, 15, 21, 23, 18, 21, 19, 16],
    [16, 16, 18, 15, 16, 22, 20, 24, 25, 23, 20, 25, 15, 16, 22, 19, 22, 16, 23, 18, 21,
     24, 22, 22, 17, 25, 15, 24, 16, 16, 18, 20, 15, 15, 16, 24, 16, 20, 17, 21],
    [25, 24, 24, 18, 20, 19, 25, 17, 19, 19, 22, 18, 19, 19, 24, 22, 22, 20, 16, 25, 19,
     25, 19, 21, 20, 24, 20, 20, 15, 24, 23, 23, 17, 15, 24, 20, 23, 19, 19, 22],
    [21, 18, 19, 21, 23, 15, 17, 19, 25, 25, 15, 20, 18, 18, 15, 21, 22, 16, 25, 17, 17,
     16, 15, 17, 24, 25, 24, 22, 23, 24, 20, 17, 20, 16, 24, 18, 21, 22, 20, 16],
    [23, 22, 15, 17, 25, 25, 24, 20, 21, 23, 17, 23, 21, 18, 18, 22, 18, 15, 15, 21, 19,
     24, 16, 19, 20, 16, 23, 17, 15, 24, 15, 24, 19, 21, 17, 16, 16, 22, 16, 24],
    [19, 17, 19, 24, 25, 23, 19, 15, 22, 23, 15, 22, 19, 19, 17, 16, 22, 19, 20, 22, 25,
     15, 24, 24, 24, 22, 22, 19, 21, 23, 24, 17, 23, 17, 20, 22, 20, 25, 19, 20],
    [17, 25, 23, 21, 21, 16, 18, 19, 20, 19, 17, 21, 23, 16, 19, 23, 23, 18, 24, 15, 19,
     22, 25, 21, 19, 17, 25, 18, 22, 21, 16, 15, 20, 15, 19, 24, 25, 18, 15, 21],
    [15, 23, 18, 15, 24, 18, 16, 24, 25, 24, 17, 25, 21, 22, 22, 18, 20, 16, 16, 23, 23,
     23, 15, 24, 20, 20, 18, 25, 16, 22, 20, 23, 15, 17, 19, 16, 18, 16, 16, 23],
    [18, 23, 24, 21, 18, 16, 18, 24, 16, 21, 21, 23, 25, 17, 19, 20, 17, 15, 23, 16, 24,
    profit = 0
    used = [0] * NUM_AGENTS
    for job, agent in enumerate(solution):
        profit += cost[agent][job]
        used[agent] += resource[agent][job]
    violation = sum(max(0, used[i] - capacity[i]) for i in range(NUM_AGENTS))
    return profit - LAMBDA * violation

def true_profit_and_feasibility(solution):
    """Return (profit, feasible_flag) without penalty."""
    profit = 0
    used = [0] * NUM_AGENTS
    for job, agent in enumerate(solution):
        profit += cost[agent][job]
        used[agent] += resource[agent][job]
    feasible = all(used[i] <= capacity[i] for i in range(NUM_AGENTS))
    return profit, feasible

def generate_neighbour(source, partner):
    """Discrete neighbour: copy partner or random agent for one job."""
    new_sol = source.copy()
    job = random.randint(0, NUM_JOBS - 1)
    if random.random() < 0.5:
        new_sol[job] = partner[job]
    else:
        new_sol[job] = random.randint(0, NUM_AGENTS - 1)
    return new_sol

def abc_gap(Np, T, limit, seed=None):
    """Run ABC and return (best_solution, best_true_profit, convergence_history)."""
    if seed is not None:
        random.seed(seed)
        np.random.seed(seed)

    # Initialisation
    population = []
    fitness = []
    trial = []
    for _ in range(Np):
        sol = [random.randint(0, NUM_AGENTS - 1) for _ in range(NUM_JOBS)]
        fit = evaluate(sol)
        population.append(sol)
        fitness.append(fit)
        trial.append(0)

    # Best tracking
    best_idx = np.argmax(fitness)
    best_sol = population[best_idx].copy()
    best_true_profit, _ = true_profit_and_feasibility(best_sol)
    history = []   # best true profit per generation

    for gen in range(T):
        # Employed Bee Phase
        for i in range(Np):
            partner = random.choice([p for p in range(Np) if p != i])
            new_sol = generate_neighbour(population[i], population[partner])
            new_fit = evaluate(new_sol)
            if new_fit > fitness[i]:
                population[i] = new_sol
                fitness[i] = new_fit
                trial[i] = 0
            else:
                trial[i] += 1

        # Probability calculation (shift if necessary)
        total_fit = sum(fitness)
        if total_fit <= 0:
            shift = -total_fit + 1e-6
            prob = [(f + shift) / (total_fit + shift * Np) for f in fitness]
        else:
            prob = [f / total_fit for f in fitness]

        # Onlooker Bee Phase
        m = 0
        n = 0
        while m < Np:
            if random.random() < prob[n]:
                partner = random.choice([p for p in range(Np) if p != n])
                new_sol = generate_neighbour(population[n], population[partner])
                new_fit = evaluate(new_sol)
                if new_fit > fitness[n]:
                    population[n] = new_sol
                    fitness[n] = new_fit
                    trial[n] = 0
                else:
                    trial[n] += 1
                m += 1
            n = (n + 1) % Np

        # Scout Bee Phase
        for i in range(Np):
            if trial[i] > limit:
                new_sol = [random.randint(0, NUM_AGENTS - 1) for _ in range(NUM_JOBS)]
                new_fit = evaluate(new_sol)
                population[i] = new_sol
                fitness[i] = new_fit
                trial[i] = 0

        # Update best solution
        current_best_idx = np.argmax(fitness)
        current_best_sol = population[current_best_idx]
        current_true_profit, _ = true_profit_and_feasibility(current_best_sol)
        if current_true_profit > best_true_profit:
            best_true_profit = current_true_profit
            best_sol = current_best_sol.copy()
        history.append(best_true_profit)

    return best_sol, best_true_profit, history

# ------------------------------------------------------------
# Main: run 20 times, collect statistics, plot convergence
# ------------------------------------------------------------

def main():
    NUM_RUNS = 20
    results = []
    all_histories = []   # store history of each run
    best_profit_overall = -float('inf')
    best_solution_overall = None
    best_run_history = None

    print("Running ABC 20 times...\n")
    for run in range(1, NUM_RUNS + 1):
        start_time = time.time()
        sol, profit, history = abc_gap(Np=100, T=700, limit=100, seed=run)
        elapsed = time.time() - start_time
        _, feasible = true_profit_and_feasibility(sol)
        results.append((profit, elapsed, feasible))
        all_histories.append(history)
        if profit > best_profit_overall:
            best_profit_overall = profit
            best_solution_overall = sol
            best_run_history = history
        print(f"Run {run:2d}: Profit = {profit:.2f}, Time = {elapsed:.2f} s, Feasible = {feasible}")

    # Summary statistics
    profits = [r[0] for r in results]
    times = [r[1] for r in results]
    feasible_count = sum(1 for r in results if r[2])
    avg_profit = np.mean(profits)
    std_profit = np.std(profits)
    best_profit = max(profits)
    worst_profit = min(profits)
    avg_time = np.mean(times)
    total_time = sum(times)

    print("\n=== Summary over {} runs ===".format(NUM_RUNS))
    print(f"Average profit    : {avg_profit:.2f} ± {std_profit:.2f}")
    print(f"Best profit       : {best_profit:.2f}")
    print(f"Worst profit      : {worst_profit:.2f}")
    print(f"Feasible runs     : {feasible_count}/{NUM_RUNS}")
    print(f"Average time      : {avg_time:.2f} s")
    print(f"Total time        : {total_time:.2f} s")

    # --- NEW PLOT: all 20 runs + average ---
    plt.figure(figsize=(12, 6))
    generations = range(700)   # T = 700

    # Plot each run with low opacity
    for hist in all_histories:
        plt.plot(generations, hist, color='blue', alpha=0.2, linewidth=0.8)

    # Compute and plot average convergence
    avg_history = np.mean(all_histories, axis=0)
    plt.plot(generations, avg_history, color='red', linewidth=2.5, label='Average (20 runs)')

    plt.xlabel('Generation', fontsize=12)
    plt.ylabel('Best True Profit', fontsize=12)
    plt.title('Convergence of ABC over 20 Runs', fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.savefig('abc_all_runs_convergence.png', dpi=150)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Running ABC 20 times...
#
# Run  1: Profit = 898.00, Time = 3.08 s, Feasible = True
# Run  2: Profit = 901.00, Time = 3.03 s, Feasible = True
# Run  3: Profit = 910.00, Time = 3.24 s, Feasible = True
# Run  4: Profit = 888.00, Time = 3.33 s, Feasible = True
# Run  5: Profit = 910.00, Time = 3.17 s, Feasible = True
# Run  6: Profit = 907.00, Time = 3.07 s, Feasible = True
# Run  7: Profit = 903.00, Time = 3.07 s, Feasible = True
# Run  8: Profit = 893.00, Time = 3.00 s, Feasible = True
# Run  9: Profit = 901.00, Time = 2.56 s, Feasible = True
# Run 10: Profit = 897.00, Time = 3.08 s, Feasible = True
# Run 11: Profit = 914.00, Time = 2.79 s, Feasible = True
# Run 12: Profit = 909.00, Time = 3.15 s, Feasible = True
# Run 13: Profit = 894.00, Time = 2.74 s, Feasible = True
# Run 14: Profit = 923.00, Time = 2.90 s, Feasible = True
# Run 15: Profit = 899.00, Time = 2.61 s, Feasible = True
# Run 16: Profit = 891.00, Time = 3.11 s, Feasible = True
# Run 17: Profit = 895.00, Time = 2.96 s, Feasible = True
# Run 18: Profit = 899.00, Time = 3.00 s, Feasible = True
# Run 19: Profit = 919.00, Time = 3.03 s, Feasible = True
# Run 20: Profit = 906.00, Time = 2.87 s, Feasible = True
#
# === Summary over 20 runs ===
# Average profit    : 902.85 ± 9.08
# Best profit       : 923.00
# Worst profit      : 888.00
# Feasible runs     : 20/20
# Average time      : 2.99 s
# Total time        : 59.80 s
