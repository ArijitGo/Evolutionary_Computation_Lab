# %%
#GAP-12, Optimal-1451

cost = [
[25,18,15,16,18,25,19,18,25,23,19,25,19,21,24,16,18,23,18,17,25,20,24,21,17,19,24,25,17,19,19,25,20,17,21,20,20,17,19,25,25,19,23,24,20,16,21,24,17,15,17,19,15,21,25,16,21,20,24,22],

[21,21,15,23,23,22,20,22,21,24,20,19,23,24,23,23,22,22,15,18,20,19,20,24,22,20,20,20,20,17,20,24,18,19,22,17,21,17,19,17,22,22,18,22,20,17,19,15,15,19,23,22,24,23,17,21,25,23,20,19],

[21,17,24,17,24,15,22,24,20,18,21,23,19,24,23,22,22,21,16,18,21,22,25,22,17,25,22,22,24,22,25,20,16,19,23,20,18,23,23,19,19,21,17,22,15,16,23,24,17,22,23,18,24,16,20,25,19,17,22,21],

[21,20,22,15,23,24,25,22,18,16,23,24,20,21,15,21,17,20,24,22,24,25,16,17,18,20,25,18,24,24,24,22,19,20,15,20,17,19,16,23,15,22,22,24,15,16,20,17,21,24,24,24,24,25,19,24,25,16,22,19],

[24,23,22,19,18,16,23,18,22,24,25,16,23,21,17,18,19,17,25,17,18,23,24,18,24,23,23,15,19,18,24,19,19,24,24,24,15,21,21,24,24,19,23,24,21,23,24,22,18,19,24,15,17,17,25,17,24,16,19,21],

[16,21,19,22,16,16,17,23,25,16,18,22,15,25,20,15,18,23,22,16,17,17,16,24,24,16,17,23,19,23,15,17,24,19,24,24,24,16,22,16,18,23,23,20,16,25,23,17,18,23,24,19,22,19,19,18,21,21,22,17],

[23,23,19,18,19,19,21,24,22,16,17,25,24,17,23,17,20,25,25,22,17,24,17,17,23,23,16,17,19,19,23,24,17,25,18,19,18,16,17,17,24,23,17,19,15,23,22,17,23,21,15,19,18,22,23,16,16,22,16,21],

[24,16,15,25,16,15,20,20,22,18,21,19,21,19,17,17,17,22,25,17,20,25,15,17,20,16,23,20,23,22,23,15,21,24,21,23,19,24,17,24,25,18,24,21,20,18,22,15,16,18,23,24,25,20,20,21,17,15,24,21],

[18,18,18,19,18,24,22,19,25,15,16,23,17,16,18,22,21,18,21,18,20,18,16,24,17,22,24,18,22,18,24,23,23,25,20,23,18,22,21,18,24,17,15,25,23,16,22,24,18,21,16,24,22,18,25,23,23,18,16,22],

[16,18,19,18,18,24,24,23,25,16,20,22,25,16,20,18,19,24,24,25,22,23,23,24,18,24,16,21,17,22,22,16,15,17,19,23,15,19,22,22,23,23,16,20,22,24,20,20,23,16,24,17,22,17,19,25,16,16,19,16]
]

resource = [
[17,25,6,14,16,12,19,19,5,16,23,16,15,22,19,10,25,7,24,9,7,24,22,23,10,25,21,16,13,17,9,6,16,23,11,22,14,22,5,14,9,19,24,16,6,21,19,11,22,22,19,24,12,20,15,17,21,17,25,19],

[6,24,12,24,14,22,11,10,25,12,20,17,18,22,11,15,20,20,21,12,5,5,25,15,24,17,7,21,11,12,24,16,12,5,9,11,14,7,14,9,13,7,25,12,6,10,7,15,13,22,6,10,5,21,5,16,16,13,5,23],

[21,21,7,5,20,16,9,14,22,12,9,8,14,17,22,9,17,8,12,15,24,19,6,8,16,14,14,23,14,23,5,21,17,25,13,23,23,12,20,19,16,15,22,19,18,7,5,20,19,9,23,14,14,11,20,15,25,17,12,13],

[22,14,19,7,5,20,19,5,20,7,12,8,13,18,16,9,23,16,16,9,25,8,13,16,6,8,5,18,12,5,12,16,12,25,5,24,23,23,25,22,17,17,21,24,16,7,17,9,13,24,22,25,25,23,12,12,8,24,14,8],

[17,10,18,13,14,18,6,6,11,9,12,20,15,12,18,18,11,7,9,25,13,9,10,9,15,10,19,15,15,14,25,6,12,21,9,10,18,20,13,17,17,21,15,9,22,11,14,14,13,16,12,5,14,18,24,9,19,14,9,24],

[24,23,6,13,9,17,18,21,10,15,15,18,14,15,11,24,20,24,16,20,23,25,9,21,21,13,9,24,12,8,14,21,16,25,20,23,8,16,20,10,5,16,11,20,10,11,21,15,12,12,21,10,19,18,10,25,23,16,8,25],

[5,21,24,13,21,11,18,12,24,22,20,21,16,18,8,25,7,19,11,12,18,5,15,7,12,5,23,16,12,5,8,24,25,10,13,24,22,20,12,16,18,9,21,17,19,6,21,12,6,9,24,10,8,13,13,13,23,25,8,22],

[9,19,23,7,5,8,16,17,21,15,15,12,21,24,15,6,7,11,5,13,10,16,19,9,22,8,21,17,7,8,25,23,20,8,14,16,5,16,5,10,17,6,18,9,19,9,11,18,23,14,24,13,20,10,22,19,6,15,18,15],

[23,15,16,20,19,23,8,15,24,25,25,5,13,14,12,25,5,11,23,24,18,7,17,10,25,21,13,19,18,6,8,9,21,18,5,12,8,7,19,24,7,9,22,7,9,10,14,24,22,24,15,16,11,19,18,18,16,8,6,8],

[10,14,24,13,18,11,13,24,22,7,12,17,23,12,15,5,5,16,20,22,18,12,20,12,9,5,7,6,25,6,7,13,7,23,21,21,18,8,23,7,11,9,15,19,9,13,22,24,18,14,11,15,15,18,22,13,17,14,11,11]
]

capacity = [79, 67, 74, 73, 67, 78, 73, 68, 73, 69]

# %%
# using penalty

import numpy as np
import time
import matplotlib.pyplot as plt

# ====================== PSO Parameters ======================
cost = np.array(cost)
resource = np.array(resource)
capacity = np.array(capacity)
n_agents = 10
n_jobs = 60
swarm_size = 60
max_iter = 800
w_start = 0.9
w_end = 0.4
c1 = 2.0
c2 = 2.0
v_max = 2.0
penalty = 1e6
pos_min = 1.0
pos_max = 11.0 - 1e-6

# ====================== Fitness Function ======================
def evaluate(x):
    a = np.floor(x).astype(int) - 1          # 0-based agent indices
    profit = np.sum(cost[a, np.arange(n_jobs)])
    used = np.zeros(n_agents)
    for job, agent in enumerate(a):
        used[agent] += resource[agent, job]
    excess = np.sum(np.maximum(0, used - capacity))
    fitness = profit - penalty * excess
    return fitness, a, profit, excess

# ====================== Repair Heuristic ======================
def repair_solution(assign, profit):
    assign = assign.copy()
    used = np.zeros(n_agents)
    for job, agent in enumerate(assign):
        used[agent] += resource[agent, job]
    overloaded = np.where(used - capacity > 0)[0].tolist()
    while overloaded:
        best_delta = -np.inf
        best_move = None
        for i in overloaded:
            jobs_i = [j for j, a in enumerate(assign) if a == i]
            for j in jobs_i:
                for k in range(n_agents):
                    if k == i:
                        continue
                    if used[k] + resource[k, j] <= capacity[k] + 1e-6:
                        delta = cost[k, j] - cost[i, j]
                        if delta > best_delta:
                            best_delta = delta
                            best_move = (j, i, k)
        if best_move is None:
            break
        j, i, k = best_move
        used[i] -= resource[i, j]
        used[k] += resource[k, j]
        assign[j] = k
        profit += best_delta
        overloaded = np.where(used - capacity > 0)[0].tolist()
    return assign, profit

# ====================== Single PSO Run with History ======================
def run_pso():
    start = time.time()

    # Initialize
    positions = np.random.uniform(pos_min, pos_max, (swarm_size, n_jobs))
    velocities = np.random.uniform(-1, 1, (swarm_size, n_jobs))

    fitness = np.zeros(swarm_size)
    profits = []
    excesses = []
    for i in range(swarm_size):
        f, a, p, e = evaluate(positions[i])
        fitness[i] = f
        profits.append(p)
        excesses.append(e)

    pbest_pos = positions.copy()
    pbest_fit = fitness.copy()
    pbest_profits = profits.copy()
    pbest_excess = excesses.copy()

    gbest_idx = np.argmax(pbest_fit)
    gbest_pos = pbest_pos[gbest_idx].copy()
    gbest_fit = pbest_fit[gbest_idx]
    gbest_profit = pbest_profits[gbest_idx]
    gbest_excess = pbest_excess[gbest_idx]

    history = []          # store global best fitness at each iteration

    # Main loop
    for t in range(max_iter):
        w = w_start - (w_start - w_end) * (t / max_iter)
        for i in range(swarm_size):
            r1 = np.random.random(n_jobs)
            r2 = np.random.random(n_jobs)
            velocities[i] = (w * velocities[i] +
                             c1 * r1 * (pbest_pos[i] - positions[i]) +
                             c2 * r2 * (gbest_pos - positions[i]))
            velocities[i] = np.clip(velocities[i], -v_max, v_max)
            positions[i] += velocities[i]
            positions[i] = np.clip(positions[i], pos_min, pos_max - 1e-6)

            f, a, p, e = evaluate(positions[i])
            if f > pbest_fit[i]:
                pbest_fit[i] = f
                pbest_pos[i] = positions[i].copy()
                pbest_profits[i] = p
                pbest_excess[i] = e
                if f > gbest_fit:
                    gbest_fit = f
                    gbest_pos = positions[i].copy()
                    gbest_profit = p
                    gbest_excess = e

        # Record global best fitness of this iteration
        history.append(gbest_fit)

    # Best found
    final_assign = np.floor(gbest_pos).astype(int) - 1
    final_profit = gbest_profit
    final_excess = gbest_excess
    feasible = (final_excess == 0)

    # Repair if infeasible
    if not feasible:
        final_assign, final_profit = repair_solution(final_assign, final_profit)
        feasible = True

    # Final feasibility check
    used_final = np.zeros(n_agents)
    for job, agent in enumerate(final_assign):
        used_final[agent] += resource[agent, job]
    excess_final = np.sum(np.maximum(0, used_final - capacity))
    feasible = (excess_final <= 1e-6)

    elapsed = time.time() - start
    return final_profit, elapsed, feasible, history

# ====================== Run 20 Times and Collect Histories ======================
n_runs = 20
profits = []
times = []
feasibilities = []
histories = []          # list of lists, each of length max_iter

print(f"Running PSO {n_runs} times...\n")
for run in range(1, n_runs + 1):
    profit, elapsed, feasible, hist = run_pso()
    profits.append(profit)
    times.append(elapsed)
    feasibilities.append(feasible)
    histories.append(hist)
    print(f"Run {run:2d}: Profit = {profit:.2f}, Time = {elapsed:.2f} s, Feasible = {feasible}")

# Statistics
profits = np.array(profits)
times = np.array(times)
print("\n=== Summary over 20 runs ===")
print(f"Average profit   : {np.mean(profits):.2f} ± {np.std(profits):.2f}")
print(f"Best profit      : {np.max(profits):.2f}")
print(f"Worst profit     : {np.min(profits):.2f}")
print(f"Average time     : {np.mean(times):.2f} s")
print(f"Total time       : {np.sum(times):.2f} s")
print(f"All runs feasible: {all(feasibilities)}")

# ====================== Plot Convergence ======================
plt.figure(figsize=(10, 6))

# Plot each run's history with low opacity
for i, hist in enumerate(histories):
    plt.plot(range(1, max_iter+1), hist, alpha=0.3, color='blue', linewidth=0.8)

# Compute and plot average history
avg_history = np.mean(histories, axis=0)
plt.plot(range(1, max_iter+1), avg_history, color='red', linewidth=2, label='Average')

plt.xlabel('Iteration')
plt.ylabel('Fitness (Profit - Penalty × Excess)')
plt.title('Convergence of PSO over 20 runs')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Running PSO 20 times...
#
# Run  1: Profit = 1314.00, Time = 3.99 s, Feasible = True
# Run  2: Profit = 1249.00, Time = 3.95 s, Feasible = True
# Run  3: Profit = 1283.00, Time = 3.93 s, Feasible = True
# Run  4: Profit = 1294.00, Time = 4.29 s, Feasible = True
# Run  5: Profit = 1243.00, Time = 4.63 s, Feasible = True
# Run  6: Profit = 1263.00, Time = 4.14 s, Feasible = True
# Run  7: Profit = 1277.00, Time = 3.60 s, Feasible = True
# Run  8: Profit = 1293.00, Time = 3.53 s, Feasible = True
# Run  9: Profit = 1274.00, Time = 3.61 s, Feasible = True
# Run 10: Profit = 1304.00, Time = 3.77 s, Feasible = True
# Run 11: Profit = 1273.00, Time = 3.73 s, Feasible = True
# Run 12: Profit = 1229.00, Time = 3.69 s, Feasible = True
# Run 13: Profit = 1284.00, Time = 4.04 s, Feasible = True
# Run 14: Profit = 1276.00, Time = 3.99 s, Feasible = True
# Run 15: Profit = 1261.00, Time = 4.03 s, Feasible = True
# Run 16: Profit = 1302.00, Time = 4.12 s, Feasible = True
# Run 17: Profit = 1252.00, Time = 3.67 s, Feasible = True
# Run 18: Profit = 1281.00, Time = 3.46 s, Feasible = True
# Run 19: Profit = 1221.00, Time = 3.46 s, Feasible = True
# Run 20: Profit = 1285.00, Time = 3.38 s, Feasible = True
#
# === Summary over 20 runs ===
# Average profit   : 1272.90 ± 24.06
# Best profit      : 1314.00
# Worst profit     : 1221.00
# Average time     : 3.85 s
# Total time       : 77.03 s
# All runs feasible: True

# %%
#GAP-8, Optimal-1133

cost = [
    [21, 25, 18, 18, 21, 25, 22, 18, 18, 23, 17, 24, 16, 21, 24, 20, 23, 24, 23, 24, 19,
     24, 21, 20, 25, 24, 22, 23, 18, 25, 20, 17, 17, 20, 17, 17, 23, 19, 18, 15, 19, 24,
     24, 25, 16, 23, 17, 18],
    [19, 16, 22, 23, 24, 21, 18, 18, 17, 17, 25, 21, 24, 17, 17, 22, 15, 24, 18, 21, 21,
     23, 19, 24, 19, 22, 17, 18, 24, 24, 21, 24, 16, 21, 23, 22, 19, 20, 24, 20, 19, 21,
     24, 25, 22, 15, 19, 16],
    [23, 19, 16, 20, 20, 18, 24, 15, 24, 17, 24, 21, 15, 19, 22, 20, 20, 24, 20, 16, 17,
     19, 18, 18, 17, 24, 23, 15, 16, 22, 25, 24, 22, 16, 25, 20, 16, 20, 18, 15, 24, 24,
     15, 24, 23, 24, 18, 25],
    [16, 16, 21, 22, 20, 22, 22, 19, 25, 16, 18, 19, 22, 19, 18, 22, 25, 20, 23, 17, 18,
     21, 16, 20, 16, 15, 21, 20, 18, 16, 23, 16, 22, 22, 18, 22, 17, 15, 15, 18, 15, 20,
     15, 21, 19, 23, 17, 25],
    [16, 15, 22, 23, 16, 23, 20, 20, 23, 16, 19, 16, 18, 20, 18, 22, 16, 15, 22, 24, 24,
     21, 22, 16, 19, 22, 17, 20, 20, 21, 15, 15, 21, 16, 16, 15, 15, 16, 24, 25, 19, 24,
     22, 22, 20, 19, 17, 24],
    [24, 19, 21, 21, 25, 24, 20, 25, 21, 24, 18, 21, 21, 15, 23, 24, 18, 23, 20, 25, 22,
     20, 17, 25, 16, 22, 19, 18, 22, 25, 16, 16, 22, 23, 22, 23, 16, 21, 17, 21, 20, 16,
     15, 23, 24, 24, 18, 22],
    [24, 23, 18, 22, 25, 18, 16, 21, 24, 25, 18, 16, 16, 23, 25, 15, 16, 19, 18, 20, 19,
     18, 24, 18, 22, 16, 25, 25, 22, 18, 16, 17, 15, 25, 24, 23, 23, 21, 25, 22, 24, 19,
     16, 21, 16, 15, 16, 25],
    [15, 21, 23, 24, 17, 23, 23, 20, 18, 17, 16, 25, 16, 22, 20, 17, 21, 18, 17, 17, 18,
     24, 24, 24, 24, 18, 20, 21, 23, 24, 19, 18, 18, 19, 22, 16, 23, 16, 17, 22, 18, 21,
     24, 25, 25, 22, 18, 19]
]

resource = [
    [7, 6, 8, 6, 13, 16, 9, 14, 15, 5, 10, 6, 10, 7, 11, 10, 13, 7, 11, 11, 9,
     15, 10, 11, 10, 14, 16, 7, 12, 12, 7, 11, 15, 16, 11, 8, 13, 10, 5, 7, 6, 9,
     6, 5, 11, 9, 13, 10],
    [10, 7, 5, 10, 16, 14, 15, 10, 16, 15, 16, 16, 5, 12, 16, 6, 12, 12, 10, 9, 15,
     11, 13, 8, 12, 10, 13, 14, 12, 13, 9, 7, 8, 14, 6, 14, 15, 12, 10, 9, 7, 7,
     9, 16, 6, 5, 13, 13],
    [16, 8, 13, 16, 16, 11, 5, 14, 10, 5, 12, 13, 12, 15, 16, 5, 16, 5, 15, 6, 7,
     9, 13, 13, 11, 9, 14, 13, 8, 12, 5, 13, 8, 9, 14, 7, 13, 14, 8, 9, 14, 14,
     12, 10, 10, 5, 14, 8],
    [15, 7, 5, 7, 14, 15, 12, 6, 5, 9, 13, 16, 10, 6, 15, 9, 15, 5, 16, 6, 11,
     13, 15, 8, 13, 9, 12, 13, 14, 15, 12, 14, 8, 14, 6, 12, 15, 8, 12, 5, 10, 6,
     14, 7, 16, 14, 10, 9],
    [8, 10, 9, 14, 7, 10, 7, 12, 10, 13, 16, 5, 14, 15, 7, 12, 16, 13, 11, 10, 5,
     10, 15, 10, 8, 5, 8, 7, 6, 6, 6, 15, 7, 6, 14, 12, 9, 6, 6, 16, 12, 15,
     15, 10, 8, 16, 7, 5],
    [13, 9, 11, 13, 5, 8, 13, 7, 10, 8, 10, 11, 5, 15, 14, 6, 8, 13, 8, 8, 9,
     12, 6, 11, 15, 6, 15, 7, 16, 16, 13, 16, 8, 15, 7, 5, 15, 11, 12, 5, 11, 13,
     12, 9, 10, 7, 10, 13],
    [16, 15, 14, 10, 8, 14, 8, 11, 11, 8, 11, 8, 16, 8, 12, 8, 16, 12, 15, 12, 6,
     9, 11, 5, 5, 8, 16, 16, 7, 14, 11, 7, 11, 14, 15, 8, 13, 14, 11, 7, 12, 16,
     6, 12, 8, 15, 11, 14],
    [12, 13, 7, 14, 7, 10, 5, 7, 8, 5, 8, 9, 10, 16, 6, 5, 9, 5, 15, 12, 7,
     13, 10, 16, 9, 10, 16, 5, 16, 11, 7, 10, 16, 8, 15, 6, 10, 12, 12, 7, 7, 13,
     5, 11, 15, 8, 10, 6]
]

capacity = [48, 53, 52, 52, 48, 50, 53, 47]

# %%
# using penalty

import numpy as np
import time
import matplotlib.pyplot as plt

# ====================== PSO Parameters ======================
cost = np.array(cost)
resource = np.array(resource)
capacity = np.array(capacity)
n_agents = 8
n_jobs = 48
swarm_size = 48
max_iter = 800
w_start = 0.9
w_end = 0.5
c1 = 1.8
c2 = 1.8
v_max = 2.0
penalty = 1e6
pos_min = 1.0
pos_max = 9.0 - 1e-6

# ====================== Fitness Function ======================
def evaluate(x):
    a = np.floor(x).astype(int) - 1          # 0-based agent indices
    profit = np.sum(cost[a, np.arange(n_jobs)])
    used = np.zeros(n_agents)
    for job, agent in enumerate(a):
        used[agent] += resource[agent, job]
    excess = np.sum(np.maximum(0, used - capacity))
    fitness = profit - penalty * excess
    return fitness, a, profit, excess

# ====================== Repair Heuristic ======================
def repair_solution(assign, profit):
    assign = assign.copy()
    used = np.zeros(n_agents)
    for job, agent in enumerate(assign):
        used[agent] += resource[agent, job]
    overloaded = np.where(used - capacity > 0)[0].tolist()
    while overloaded:
        best_delta = -np.inf
        best_move = None
        for i in overloaded:
            jobs_i = [j for j, a in enumerate(assign) if a == i]
            for j in jobs_i:
                for k in range(n_agents):
                    if k == i:
                        continue
                    if used[k] + resource[k, j] <= capacity[k] + 1e-6:
                        delta = cost[k, j] - cost[i, j]
                        if delta > best_delta:
                            best_delta = delta
                            best_move = (j, i, k)
        if best_move is None:
            break
        j, i, k = best_move
        used[i] -= resource[i, j]
        used[k] += resource[k, j]
        assign[j] = k
        profit += best_delta
        overloaded = np.where(used - capacity > 0)[0].tolist()
    return assign, profit

# ====================== Single PSO Run with History ======================
def run_pso():
    start = time.time()

    # Initialize
    positions = np.random.uniform(pos_min, pos_max, (swarm_size, n_jobs))
    velocities = np.random.uniform(-1, 1, (swarm_size, n_jobs))

    fitness = np.zeros(swarm_size)
    profits = []
    excesses = []
    for i in range(swarm_size):
        f, a, p, e = evaluate(positions[i])
        fitness[i] = f
        profits.append(p)
        excesses.append(e)

    pbest_pos = positions.copy()
    pbest_fit = fitness.copy()
    pbest_profits = profits.copy()
    pbest_excess = excesses.copy()

    gbest_idx = np.argmax(pbest_fit)
    gbest_pos = pbest_pos[gbest_idx].copy()
    gbest_fit = pbest_fit[gbest_idx]
    gbest_profit = pbest_profits[gbest_idx]
    gbest_excess = pbest_excess[gbest_idx]

    history = []          # store global best fitness at each iteration

    # Main loop
    for t in range(max_iter):
        w = w_start - (w_start - w_end) * (t / max_iter)
        for i in range(swarm_size):
            r1 = np.random.random(n_jobs)
            r2 = np.random.random(n_jobs)
            velocities[i] = (w * velocities[i] +
                             c1 * r1 * (pbest_pos[i] - positions[i]) +
                             c2 * r2 * (gbest_pos - positions[i]))
            velocities[i] = np.clip(velocities[i], -v_max, v_max)
            positions[i] += velocities[i]
            positions[i] = np.clip(positions[i], pos_min, pos_max - 1e-6)

            f, a, p, e = evaluate(positions[i])
            if f > pbest_fit[i]:
                pbest_fit[i] = f
                pbest_pos[i] = positions[i].copy()
                pbest_profits[i] = p
                pbest_excess[i] = e
                if f > gbest_fit:
                    gbest_fit = f
                    gbest_pos = positions[i].copy()
                    gbest_profit = p
                    gbest_excess = e

        # Record global best fitness of this iteration
        history.append(gbest_fit)

    # Best found
    final_assign = np.floor(gbest_pos).astype(int) - 1
    final_profit = gbest_profit
    final_excess = gbest_excess
    feasible = (final_excess == 0)

    # Repair if infeasible
    if not feasible:
        final_assign, final_profit = repair_solution(final_assign, final_profit)
        feasible = True

    # Final feasibility check
    used_final = np.zeros(n_agents)
    for job, agent in enumerate(final_assign):
        used_final[agent] += resource[agent, job]
    excess_final = np.sum(np.maximum(0, used_final - capacity))
    feasible = (excess_final <= 1e-6)

    elapsed = time.time() - start
    return final_profit, elapsed, feasible, history

# ====================== Run 20 Times and Collect Histories ======================
n_runs = 20
profits = []
times = []
feasibilities = []
histories = []          # list of lists, each of length max_iter

print(f"Running PSO {n_runs} times...\n")
for run in range(1, n_runs + 1):
    profit, elapsed, feasible, hist = run_pso()
    profits.append(profit)
    times.append(elapsed)
    feasibilities.append(feasible)
    histories.append(hist)
    print(f"Run {run:2d}: Profit = {profit:.2f}, Time = {elapsed:.2f} s, Feasible = {feasible}")

# Statistics
profits = np.array(profits)
times = np.array(times)
print("\n=== Summary over 20 runs ===")
print(f"Average profit   : {np.mean(profits):.2f} ± {np.std(profits):.2f}")
print(f"Best profit      : {np.max(profits):.2f}")
print(f"Worst profit     : {np.min(profits):.2f}")
print(f"Average time     : {np.mean(times):.2f} s")
print(f"Total time       : {np.sum(times):.2f} s")
print(f"All runs feasible: {all(feasibilities)}")

# ====================== Plot Convergence ======================
plt.figure(figsize=(10, 6))

# Plot each run's history with low opacity
for i, hist in enumerate(histories):
    plt.plot(range(1, max_iter+1), hist, alpha=0.3, color='blue', linewidth=0.8)

# Compute and plot average history
avg_history = np.mean(histories, axis=0)
plt.plot(range(1, max_iter+1), avg_history, color='red', linewidth=2, label='Average')

plt.xlabel('Iteration')
plt.ylabel('Fitness (Profit - Penalty × Excess)')
plt.title('Convergence of PSO over 20 runs')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Running PSO 20 times...
#
# Run  1: Profit = 1015.00, Time = 2.79 s, Feasible = True
# Run  2: Profit = 976.00, Time = 2.54 s, Feasible = False
# Run  3: Profit = 996.00, Time = 2.60 s, Feasible = False
# Run  4: Profit = 990.00, Time = 2.56 s, Feasible = True
# Run  5: Profit = 970.00, Time = 2.68 s, Feasible = False
# Run  6: Profit = 980.00, Time = 2.56 s, Feasible = False
# Run  7: Profit = 987.00, Time = 2.55 s, Feasible = True
# Run  8: Profit = 1011.00, Time = 2.55 s, Feasible = True
# Run  9: Profit = 1003.00, Time = 2.86 s, Feasible = True
# Run 10: Profit = 1029.00, Time = 2.56 s, Feasible = False
# Run 11: Profit = 1009.00, Time = 2.58 s, Feasible = True
# Run 12: Profit = 1006.00, Time = 2.57 s, Feasible = False
# Run 13: Profit = 1011.00, Time = 2.71 s, Feasible = True
# Run 14: Profit = 1032.00, Time = 2.56 s, Feasible = True
# Run 15: Profit = 966.00, Time = 2.55 s, Feasible = True
# Run 16: Profit = 1029.00, Time = 2.55 s, Feasible = True
# Run 17: Profit = 1009.00, Time = 2.65 s, Feasible = False
# Run 18: Profit = 1019.00, Time = 2.65 s, Feasible = True
# Run 19: Profit = 986.00, Time = 2.56 s, Feasible = True
# Run 20: Profit = 1022.00, Time = 2.54 s, Feasible = True
#
# === Summary over 20 runs ===
# Average profit   : 1002.30 ± 19.53
# Best profit      : 1032.00
# Worst profit     : 966.00
# Average time     : 2.61 s
# Total time       : 52.17 s
# All runs feasible: False

# %%
#GAP-10, Optimal-958

cost = [
    [17, 21, 25, 19, 24, 22, 24, 20, 23, 15, 16, 17, 23, 21, 20, 21, 22, 19, 24, 22, 16,
     23, 24, 16, 24, 15, 17, 17, 19, 19, 25, 18, 21, 15, 21, 23, 18, 21, 19, 16],
    [16, 16, 18, 15, 16, 22, 20, 24, 25, 23, 20, 25, 15, 16, 22, 19, 22, 16, 23, 18, 21,
     24, 22, 22, 17, 25, 15, 24, 16, 16, 18, 20, 15, 15, 16, 24, 16, 20, 17, 21],
    [25, 24, 24, 18, 20, 19, 25, 17, 19, 19, 22, 18, 19, 19, 24, 22, 22, 20, 16, 25, 19,
     25, 19, 21, 20, 24, 20, 20, 15, 24, 23, 23, 17, 15, 24, 20, 23, 19, 19, 22],
    [21, 18, 19, 21, 23, 15, 17, 19, 25, 25, 15, 20, 18, 18, 15, 21, 22, 16, 25, 17, 17,
     16, 15, 17, 24, 25, 24, 22, 23, 24, 20, 17, 20, 16, 24, 18, 21, 22, 20, 16],
    [23, 22, 15, 17, 25, 25, 24, 20, 21, 23, 17, 23, 21, 18, 18, 22, 18, 15, 15, 21, 19,
     24, 16, 19, 20, 16, 23, 17, 15, 24, 15, 24, 19, 21, 17, 16, 16, 22, 16, 24],
    [19, 17, 19, 24, 25, 23, 19, 15, 22, 23, 15, 22, 19, 19, 17, 16, 22, 19, 20, 22, 25,
     15, 24, 24, 24, 22, 22, 19, 21, 23, 24, 17, 23, 17, 20, 22, 20, 25, 19, 20],
    [17, 25, 23, 21, 21, 16, 18, 19, 20, 19, 17, 21, 23, 16, 19, 23, 23, 18, 24, 15, 19,
     22, 25, 21, 19, 17, 25, 18, 22, 21, 16, 15, 20, 15, 19, 24, 25, 18, 15, 21],
    [15, 23, 18, 15, 24, 18, 16, 24, 25, 24, 17, 25, 21, 22, 22, 18, 20, 16, 16, 23, 23,
     23, 15, 24, 20, 20, 18, 25, 16, 22, 20, 23, 15, 17, 19, 16, 18, 16, 16, 23],
    [18, 23, 24, 21, 18, 16, 18, 24, 16, 21, 21, 23, 25, 17, 19, 20, 17, 15, 23, 16, 24,
     21, 22, 15, 19, 22, 22, 17, 25, 21, 16, 15, 21, 20, 25, 21, 16, 17, 15, 21],
    [21, 16, 17, 18, 18, 23, 18, 22, 24, 22, 21, 17, 24, 25, 24, 15, 25, 17, 15, 19, 20,
     20, 25, 25, 18, 25, 17, 21, 21, 15, 24, 16, 24, 17, 22, 15, 22, 19, 24, 17]
]

resource = [
    [9, 14, 23, 14, 12, 6, 15, 16, 15, 12, 14, 18, 9, 22, 8, 23, 6, 19, 6, 8, 8,
     15, 7, 16, 24, 5, 18, 16, 13, 13, 11, 7, 19, 19, 15, 21, 20, 18, 11, 8],
    [21, 24, 24, 19, 14, 22, 9, 24, 19, 24, 11, 23, 18, 22, 9, 9, 14, 15, 21, 5, 25,
     5, 20, 13, 7, 6, 8, 16, 21, 22, 5, 18, 10, 20, 8, 9, 14, 9, 5, 22],
    [18, 12, 6, 14, 17, 7, 24, 20, 19, 10, 13, 25, 23, 7, 6, 9, 17, 9, 6, 21, 24,
     13, 18, 5, 21, 21, 15, 11, 15, 15, 15, 18, 21, 9, 22, 8, 8, 18, 13, 12],
    [23, 7, 9, 13, 7, 17, 14, 10, 17, 9, 11, 22, 25, 19, 12, 5, 20, 5, 24, 22, 7,
     11, 24, 19, 8, 15, 9, 21, 11, 9, 15, 12, 18, 25, 8, 14, 20, 21, 22, 8],
    [7, 8, 13, 10, 12, 25, 7, 5, 14, 17, 16, 15, 10, 9, 6, 16, 6, 23, 23, 10, 16,
     5, 16, 11, 23, 15, 6, 13, 12, 21, 10, 15, 21, 12, 14, 14, 24, 22, 13, 5],
    [17, 9, 22, 8, 19, 8, 7, 11, 14, 14, 17, 23, 25, 21, 12, 20, 8, 20, 9, 5, 8,
     16, 16, 23, 22, 20, 17, 21, 11, 12, 9, 15, 21, 17, 13, 18, 23, 6, 8, 20],
    [14, 12, 24, 12, 14, 5, 24, 11, 13, 21, 15, 18, 14, 18, 5, 11, 21, 16, 5, 17, 6,
     10, 21, 11, 13, 24, 13, 25, 10, 21, 11, 22, 11, 16, 15, 17, 21, 11, 21, 24],
    [22, 20, 21, 12, 17, 24, 21, 7, 9, 23, 13, 11, 19, 17, 17, 20, 14, 10, 11, 16, 8,
     7, 21, 16, 24, 9, 16, 15, 10, 23, 10, 13, 9, 6, 18, 23, 19, 22, 13, 18],
    [6, 11, 16, 17, 6, 8, 18, 24, 19, 9, 18, 18, 7, 13, 11, 20, 19, 22, 19, 20, 14,
     10, 6, 6, 25, 7, 8, 18, 19, 17, 6, 25, 13, 12, 22, 23, 8, 12, 5, 19],
    [7, 14, 11, 6, 11, 25, 18, 10, 9, 10, 13, 23, 12, 17, 11, 14, 12, 19, 20, 8, 8,
     8, 20, 25, 19, 21, 25, 23, 23, 11, 19, 13, 21, 25, 20, 22, 16, 8, 24, 20]
]

capacity = [44, 48, 46, 47, 43, 48, 49, 49, 46, 51]

# %%
# using penalty

import numpy as np
import time
import matplotlib.pyplot as plt

# ====================== PSO Parameters ======================
cost = np.array(cost)
resource = np.array(resource)
capacity = np.array(capacity)
n_agents = 10
n_jobs = 40
swarm_size = 40
max_iter = 800
w_start = 0.9
w_end = 0.5
c1 = 1.8
c2 = 1.8
v_max = 2.0
penalty = 1e6
pos_min = 1.0
pos_max = 9.0 - 1e-6

# ====================== Fitness Function ======================
def evaluate(x):
    a = np.floor(x).astype(int) - 1          # 0-based agent indices
    profit = np.sum(cost[a, np.arange(n_jobs)])
    used = np.zeros(n_agents)
    for job, agent in enumerate(a):
        used[agent] += resource[agent, job]
    excess = np.sum(np.maximum(0, used - capacity))
    fitness = profit - penalty * excess
    return fitness, a, profit, excess

# ====================== Repair Heuristic ======================
def repair_solution(assign, profit):
    assign = assign.copy()
    used = np.zeros(n_agents)
    for job, agent in enumerate(assign):
        used[agent] += resource[agent, job]
    overloaded = np.where(used - capacity > 0)[0].tolist()
    while overloaded:
        best_delta = -np.inf
        best_move = None
        for i in overloaded:
            jobs_i = [j for j, a in enumerate(assign) if a == i]
            for j in jobs_i:
                for k in range(n_agents):
                    if k == i:
                        continue
                    if used[k] + resource[k, j] <= capacity[k] + 1e-6:
                        delta = cost[k, j] - cost[i, j]
                        if delta > best_delta:
                            best_delta = delta
                            best_move = (j, i, k)
        if best_move is None:
            break
        j, i, k = best_move
        used[i] -= resource[i, j]
        used[k] += resource[k, j]
        assign[j] = k
        profit += best_delta
        overloaded = np.where(used - capacity > 0)[0].tolist()
    return assign, profit

# ====================== Single PSO Run with History ======================
def run_pso():
    start = time.time()

    # Initialize
    positions = np.random.uniform(pos_min, pos_max, (swarm_size, n_jobs))
    velocities = np.random.uniform(-1, 1, (swarm_size, n_jobs))

    fitness = np.zeros(swarm_size)
    profits = []
    excesses = []
    for i in range(swarm_size):
        f, a, p, e = evaluate(positions[i])
        fitness[i] = f
        profits.append(p)
        excesses.append(e)

    pbest_pos = positions.copy()
    pbest_fit = fitness.copy()
    pbest_profits = profits.copy()
    pbest_excess = excesses.copy()

    gbest_idx = np.argmax(pbest_fit)
    gbest_pos = pbest_pos[gbest_idx].copy()
    gbest_fit = pbest_fit[gbest_idx]
    gbest_profit = pbest_profits[gbest_idx]
    gbest_excess = pbest_excess[gbest_idx]

    history = []          # store global best fitness at each iteration

    # Main loop
    for t in range(max_iter):
        w = w_start - (w_start - w_end) * (t / max_iter)
        for i in range(swarm_size):
            r1 = np.random.random(n_jobs)
            r2 = np.random.random(n_jobs)
            velocities[i] = (w * velocities[i] +
                             c1 * r1 * (pbest_pos[i] - positions[i]) +
                             c2 * r2 * (gbest_pos - positions[i]))
            velocities[i] = np.clip(velocities[i], -v_max, v_max)
            positions[i] += velocities[i]
            positions[i] = np.clip(positions[i], pos_min, pos_max - 1e-6)

            f, a, p, e = evaluate(positions[i])
            if f > pbest_fit[i]:
                pbest_fit[i] = f
                pbest_pos[i] = positions[i].copy()
                pbest_profits[i] = p
                pbest_excess[i] = e
                if f > gbest_fit:
                    gbest_fit = f
                    gbest_pos = positions[i].copy()
                    gbest_profit = p
                    gbest_excess = e

        # Record global best fitness of this iteration
        history.append(gbest_fit)

    # Best found
    final_assign = np.floor(gbest_pos).astype(int) - 1
    final_profit = gbest_profit
    final_excess = gbest_excess
    feasible = (final_excess == 0)

    # Repair if infeasible
    if not feasible:
        final_assign, final_profit = repair_solution(final_assign, final_profit)
        feasible = True

    # Final feasibility check
    used_final = np.zeros(n_agents)
    for job, agent in enumerate(final_assign):
        used_final[agent] += resource[agent, job]
    excess_final = np.sum(np.maximum(0, used_final - capacity))
    feasible = (excess_final <= 1e-6)

    elapsed = time.time() - start
    return final_profit, elapsed, feasible, history

# ====================== Run 20 Times and Collect Histories ======================
n_runs = 20
profits = []
times = []
feasibilities = []
histories = []          # list of lists, each of length max_iter

print(f"Running PSO {n_runs} times...\n")
for run in range(1, n_runs + 1):
    profit, elapsed, feasible, hist = run_pso()
    profits.append(profit)
    times.append(elapsed)
    feasibilities.append(feasible)
    histories.append(hist)
    print(f"Run {run:2d}: Profit = {profit:.2f}, Time = {elapsed:.2f} s, Feasible = {feasible}")

# Statistics
profits = np.array(profits)
times = np.array(times)
print("\n=== Summary over 20 runs ===")
print(f"Average profit   : {np.mean(profits):.2f} ± {np.std(profits):.2f}")
print(f"Best profit      : {np.max(profits):.2f}")
print(f"Worst profit     : {np.min(profits):.2f}")
print(f"Average time     : {np.mean(times):.2f} s")
print(f"Total time       : {np.sum(times):.2f} s")
print(f"All runs feasible: {all(feasibilities)}")

# ====================== Plot Convergence ======================
plt.figure(figsize=(10, 6))

# Plot each run's history with low opacity
for i, hist in enumerate(histories):
    plt.plot(range(1, max_iter+1), hist, alpha=0.3, color='blue', linewidth=0.8)

# Compute and plot average history
avg_history = np.mean(histories, axis=0)
plt.plot(range(1, max_iter+1), avg_history, color='red', linewidth=2, label='Average')

plt.xlabel('Iteration')
plt.ylabel('Fitness (Profit - Penalty × Excess)')
plt.title('Convergence of PSO over 20 runs')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Running PSO 20 times...
#
# Run  1: Profit = 828.00, Time = 2.31 s, Feasible = True
# Run  2: Profit = 863.00, Time = 2.26 s, Feasible = True
# Run  3: Profit = 887.00, Time = 2.33 s, Feasible = True
# Run  4: Profit = 873.00, Time = 2.14 s, Feasible = True
# Run  5: Profit = 875.00, Time = 2.02 s, Feasible = True
# Run  6: Profit = 872.00, Time = 2.04 s, Feasible = True
# Run  7: Profit = 835.00, Time = 2.00 s, Feasible = True
# Run  8: Profit = 867.00, Time = 2.07 s, Feasible = True
# Run  9: Profit = 844.00, Time = 2.26 s, Feasible = True
# Run 10: Profit = 844.00, Time = 2.40 s, Feasible = True
# Run 11: Profit = 844.00, Time = 2.45 s, Feasible = True
# Run 12: Profit = 869.00, Time = 2.48 s, Feasible = True
# Run 13: Profit = 850.00, Time = 2.19 s, Feasible = True
# Run 14: Profit = 889.00, Time = 2.04 s, Feasible = True
# Run 15: Profit = 832.00, Time = 2.02 s, Feasible = True
# Run 16: Profit = 854.00, Time = 2.04 s, Feasible = True
# Run 17: Profit = 838.00, Time = 2.01 s, Feasible = True
# Run 18: Profit = 831.00, Time = 2.43 s, Feasible = True
# Run 19: Profit = 870.00, Time = 2.41 s, Feasible = True
# Run 20: Profit = 857.00, Time = 2.37 s, Feasible = True
#
# === Summary over 20 runs ===
# Average profit   : 856.10 ± 18.32
# Best profit      : 889.00
# Worst profit     : 828.00
# Average time     : 2.21 s
# Total time       : 44.26 s
# All runs feasible: True
